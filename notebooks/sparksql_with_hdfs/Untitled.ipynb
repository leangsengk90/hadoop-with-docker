# %%
import os
import sys
from pyspark.sql import SparkSession

# Force Python to find the right Spark internal paths
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# Try to start Spark WITHOUT any extra configs or JARs
try:
    spark = SparkSession.builder.master("local[*]").appName("Test").getOrCreate()
    print("Spark is ALIVE! Version:", spark.version)
except Exception as e:
    print("Spark is STILL BROKEN. Please run the command below to check for Java.")
    print(f"Error: {e}")
# Out:
# Spark is STILL BROKEN. Please run the command below to check for Java.
# Error: 'JavaPackage' object is not callable
