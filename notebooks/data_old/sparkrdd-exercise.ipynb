# %%
# Exercise 01
import findspark
findspark.init()
from pyspark import SparkContext

sc = SparkContext(appName="Excercise01", master="spark://namenode:7077")
input_file = "/data/BattleCreekDec19_2019.txt"

# Process everything
word_counts = sc.textFile(input_file) \
                .flatMap(lambda line: line.split(" ")) \
                .filter(lambda word: word != "") \
                .map(lambda word: (word.lower().strip(), 1)) \
                .reduceByKey(lambda a, b: a + b) \
                .sortBy(lambda x: x, ascending=False) # Simplified sorting syntax

# Note: .collect() pulls everything into driver memory. 
# If the file is massive, this can cause an OutOfMemory error.
all_results = word_counts.collect()

print(f"Grand Total: {len(all_results)} unique words found.\n")

# Printing thousands of lines might lag your notebook; consider all_results[:100]
for word, count in all_results:
    print(f"'{word}': {count}")
sc.stop()
# Out:
# Grand Total: 3299 unique words found.
#
# '…"': 1
# '…': 53
# '‘well,': 1
# '‘darling,': 1
# 'zone,': 1
# 'zeros?': 1
# 'zero': 1
# 'yourself.': 1
# 'your': 60
# 'young': 3
# 'you?"': 2
# 'you?': 3
# 'you."': 4
# 'you.': 40
# 'you,': 22
# 'you've': 5
# 'you're': 40
# 'you'll': 3
# 'you'd': 3
# 'you': 392
# 'york,': 1
# 'york': 2
# 'yet,': 1
# 'yet': 3
# 'yesterday,': 2
# 'yesterday': 1
# 'yes.': 1
# 'yellow': 2
# 'years…': 1
# 'years."': 2
# 'years.': 26
# 'years,': 13
# 'years': 19
# 'year."': 1
# 'year.': 4
# 'year,': 3
# 'year': 16
# 'yeah,': 2
# 'wrong?"': 2
# 'wrong.': 3
# 'wrong,': 2
# 'wrong': 1
# 'write.': 2
# 'write,': 1
# 'write': 3
# 'wrist': 1
# 'wrapped': 1
# 'wow.': 1
# 'wow!': 1
# 'wouldn't': 8
# 'would've': 4
# 'would': 32
# 'worst': 5
# 'worse': 4
# 'worry': 7
# 'worried.': 1
# 'worried,': 1
# 'worried': 1
# 'world.': 7
# 'world,': 4
# 'world': 7
# 'working.': 1
# 'working': 1
# 'workers,': 1
# 'workers': 3
# 'worker.': 2
# 'worker,': 1
# 'worker': 1
# 'worked': 2
# 'work.': 3
# 'work,': 1
# 'work': 6
# 'wore': 1
# 'words,': 1
# 'words': 3
# 'wording,': 1
# 'word.': 4
# 'word': 5
# 'wonderful,': 2
# 'wonderful': 6
# 'wonder': 1
# 'won,': 1
# 'won't': 15
# 'won': 6
# 'women.': 1
# 'women,': 1
# 'women': 5
# 'womb,': 1
# 'womankind.': 2
# 'woman,': 2
# 'woman's': 1
# 'woman': 5
# 'without': 1
# 'within': 4
# 'withdrew': 1
# 'withdraw,"': 1
# 'withdraw,': 1
# 'with.': 1
# 'with,': 1
# 'with': 96
# 'witch': 3
# 'wisconsin."': 2
# 'wisconsin.': 2
# 'wisconsin,': 2
# 'wisconsin': 1
# 'wires,': 1
# 'winning,': 2
# 'winning': 1
# 'wine': 1
# 'win."': 1
# 'win.': 1
# 'win,': 1
# 'win': 8
# 'willing': 2
# 'will': 35
# 'wild,': 1
# 'wife,': 2
# 'wife': 1
# 'wicked': 1
# 'why?': 6
# 'why,': 1
# 'why': 16
# 'whooped?': 1
# 'whole': 6
# 'whoever.': 1
# 'who's': 6
# 'who': 16
# 'white': 2
# 'while': 6
# 'which': 11
# 'whether': 1
# 'where's': 2
# 'where': 37
# 'whenever': 1
# 'when': 30
# 'whatsoever.': 3
# 'whatever.': 2
# 'whatever': 5
# 'what?': 17
# 'what.': 3
# 'what,': 4
# 'what's': 10
# 'what': 126
# 'west.': 1
# 'weren't': 2
# 'were': 39
# 'went,': 1
# 'went': 14
# 'well."': 1
# 'well.': 7
# 'well,': 7
# 'well': 7
# 'welfare': 1
# 'weeks?': 1
# 'weeks.': 1
# 'weeks,': 3
# 'weeks': 3
# 'week': 1
# 'wear': 2
# 'weapons': 2
# 'wealthy': 1
# 'wealth.': 1
# 'weak.': 1
# 'weak,': 2
# 'weak': 1
# 'we've': 29
# 'we're': 82
# 'we'll': 10
# 'we'd': 1
# 'we': 251
# 'ways,': 1
# 'way.': 4
# 'way,': 21
# 'way': 7
# 'wave': 1
# 'water.': 1
# 'water,': 4
# 'water': 12
# 'watching': 1
# 'watcher': 1
# 'watched': 2
# 'watch."': 1
# 'watch,': 1
# 'watch': 3
# 'wasting': 1
# 'wasted': 1
# 'waste.': 1
# 'wasn't': 5
# 'washington': 6
# 'wash': 1
# 'was.': 1
# 'was,': 1
# 'was': 118
# 'ward': 1
# 'war': 2
# 'wants': 5
# 'wanted.': 1
# 'wanted': 9
# 'want?"': 1
# 'want.': 3
# 'want,': 1
# 'want': 69
# 'wand?': 1
# 'wand."': 1
# 'wall': 2
# 'walks': 2
# 'walking': 1
# 'walked': 1
# 'walk': 3
# 'waiting': 1
# 'wait,': 3
# 'wait': 3
# 'wages': 1
# 'votes,': 1
# 'voters': 1
# 'voter.': 1
# 'vote.': 1
# 'vote,': 1
# 'vote': 5
# 'virtually': 1
# 'violent': 1
# 'violating': 1
# 'violated': 4
# 'victory.': 1
# 'victory,': 1
# 'victory': 3
# 'victories': 1
# 'viciously': 1
# 'vicious.': 2
# 'vicious': 2
# 'vice': 1
# 'vets,': 1
# 'veto': 1
# 'vests?': 2
# 'very,': 3
# 'very': 31
# 'versus': 1
# 'vehicle': 1
# 'various': 1
# 'values': 1
# 'usually': 1
# 'usmca.': 1
# 'usmca': 2
# 'using': 2
# 'used?': 1
# 'used': 14
# 'use,': 1
# 'use': 8
# 'usa.': 2
# 'usa': 2
# 'us?"': 1
# 'us.': 7
# 'us,': 6
# 'us!': 2
# 'us': 21
# 'upstairs,': 1
# 'upset.': 1
# 'upheld.': 2
# 'up?"': 1
# 'up?': 5
# 'up."': 1
# 'up.': 15
# 'up,': 12
# 'up': 54
# 'until': 4
# 'unsupported?': 1
# 'unsupported!"': 1
# 'unsubstantiated.': 1
# 'unsubstantiated,': 1
# 'unsubstantiated"?': 1
# 'unpronounceable': 1
# 'unprecedented.': 1
# 'unprecedented': 1
# 'unpopular': 1
# 'unless': 2
# 'universities.': 1
# 'universities': 1
# 'united': 14
# 'unions.': 1
# 'unions': 1
# 'union': 4
# 'unheard': 1
# 'unfortunately': 1
# 'unfettered': 1
# 'unfair': 2
# 'unemployment.': 1
# 'unemployment,': 1
# 'unemployment': 2
# 'understand?': 1
# 'understand.': 1
# 'understand': 4
# 'undercount': 1
# 'under': 6
# 'unconstitutional': 1
# 'unbelievable.': 3
# 'unbelievable': 1
# 'ukraine,': 2
# 'ukraine': 3
# 'u.s.': 2
# 'type': 1
# 'two.': 1
# 'two': 34
# 'turned': 1
# 'turn': 4
# 'turley,': 1
# 'tucker': 1
# 'tubes.': 1
# 'trying': 9
# 'try?': 1
# 'try.': 2
# 'try': 3
# 'truthful,': 1
# 'truth': 1
# 'trust.': 1
# 'trump/pence': 1
# 'trump."': 1
# 'trump.': 2
# 'trump,': 4
# 'trump': 4
# 'truly': 2
# 'true.': 6
# 'true,': 2
# 'true': 3
# 'trip?"': 1
# 'trip.': 1
# 'trip,': 1
# 'trip': 2
# 'trillion.': 1
# 'trillion': 1
# 'tried': 2
# 'trend.': 1
# 'tremendous': 5
# 'tree.': 1
# 'treatment.': 2
# 'treasury.': 1
# 'traveling,': 1
# 'traveling': 2
# 'travel': 1
# 'transformed': 1
# 'transcripts?"': 1
# 'transcript.': 2
# 'trans': 1
# 'trading': 1
# 'trade.': 1
# 'trade,': 1
# 'trade': 4
# 'tpp?': 1
# 'tough.': 5
# 'tough': 5
# 'totally': 11
# 'total.': 1
# 'total': 2
# 'top': 2
# 'took': 11
# 'too.': 2
# 'too,': 1
# 'too': 13
# 'tonight?"': 1
# 'tonight.': 1
# 'tonight': 2
# 'told,': 1
# 'told': 5
# 'toilets."': 2
# 'toilets,': 1
# 'together.': 3
# 'together,': 1
# 'together': 3
# 'today.': 1
# 'today,': 2
# 'today's': 1
# 'today': 2
# 'to?': 1
# 'to.': 2
# 'to,': 2
# 'to': 422
# 'tireless': 1
# 'tiny': 1
# 'times?': 1
# 'times.': 2
# 'times,': 7
# 'times': 6
# 'time.': 13
# 'time,': 6
# 'time': 23
# 'till': 1
# 'thugs': 1
# 'throwing': 1
# 'throw': 1
# 'through.': 2
# 'through,': 1
# 'through': 17
# 'thriving': 4
# 'thrilling': 1
# 'thrilled.': 2
# 'thrilled': 1
# 'three,': 1
# 'three': 16
# 'threatens': 1
# 'thousands,': 1
# 'thousands': 6
# 'thousand': 1
# 'thought,': 1
# 'thought': 4
# 'though.': 2
# 'though,': 4
# 'though': 1
# 'those.': 1
# 'those': 30
# 'thomas': 1
# 'this?"': 1
# 'this?': 4
# 'this."': 1
# 'this.': 7
# 'this,': 12
# 'this': 87
# 'third': 1
# 'thinks,': 1
# 'thinks': 2
# 'think.': 2
# 'think,': 2
# 'think': 58
# 'things?"': 1
# 'things?': 1
# 'things.': 4
# 'things,': 2
# 'things': 9
# 'thing.': 15
# 'thing,': 7
# 'thing': 15
# 'thin': 1
# 'thieves,': 1
# 'the…': 1
# 'they…': 1
# 'they've': 17
# 'they're': 84
# 'they'll': 8
# 'they'd': 12
# 'they': 316
# 'these': 56
# 'there?"': 2
# 'there?': 2
# 'there."': 1
# 'there.': 5
# 'there,': 5
# 'there's': 17
# 'there'll': 1
# 'there'd': 1
# 'there': 11
# 'then.': 1
# 'then,': 2
# 'then': 40
# 'themselves': 1
# 'them.': 17
# 'them,': 11
# 'them': 49
# 'their': 22
# 'the': 698
# 'that?"': 1
# 'that?': 10
# 'that."': 4
# 'that.': 23
# 'that,': 27
# 'that's': 72
# 'that'll': 1
# 'that': 193
# 'thanks."': 1
# 'thanks.': 1
# 'thanks': 1
# 'thank': 38
# 'than': 40
# 'texas?': 1
# 'texas.': 2
# 'texas': 1
# 'terry.': 1
# 'terry': 1
# 'terrific.': 1
# 'terrific': 1
# 'terrible.': 5
# 'terrible': 2
# 'terminally': 3
# 'term': 4
# 'tents': 2
# 'tens': 2
# 'telling': 6
# 'tell': 28
# 'television.': 2
# 'television': 1
# 'tears': 1
# 'taxpayer': 1
# 'taxes.': 1
# 'taxes,': 1
# 'taxes': 2
# 'taxed': 2
# 'tax': 2
# 'taught': 1
# 'tariffs,': 1
# 'tariffs': 3
# 'tariff,': 1
# 'tariff': 1
# 'targeted,': 1
# 'targeted': 1
# 'target.': 1
# 'tapes': 1
# 'tape.': 1
# 'tape,': 1
# 'tape!': 1
# 'tape': 1
# 'talks': 2
# 'talking.': 1
# 'talking': 7
# 'talked': 3
# 'talk.': 1
# 'talk': 17
# 'taking': 8
# 'takes.': 1
# 'takes': 1
# 'takeover': 1
# 'taken': 1
# 'take': 33
# 'tables.': 1
# 'table.': 1
# 'table': 2
# 'system': 1
# 'swing': 1
# 'sweat': 1
# 'swamp.': 1
# 'swamp,': 3
# 'swamp': 1
# 'survival': 1
# 'surrounded': 1
# 'surrendering': 1
# 'surprised.': 2
# 'surprised': 1
# 'sure.': 1
# 'sure': 1
# 'supreme': 5
# 'suppression': 1
# 'supports': 1
# 'supporting': 2
# 'supported': 4
# 'support.': 1
# 'support,': 1
# 'support': 2
# 'super': 2
# 'suicide': 1
# 'suffering': 1
# 'sued.': 1
# 'sue': 2
# 'sudden,': 1
# 'sudden': 1
# 'suckers,': 1
# 'such': 3
# 'successful,': 1
# 'subverting': 1
# 'subsidy.': 1
# 'subsidy': 1
# 'submarines,': 1
# 'submarine."': 1
# 'stupid."': 1
# 'stupid.': 1
# 'stupid': 1
# 'stuff."': 1
# 'stuff.': 2
# 'stuff,': 5
# 'stuff': 2
# 'stuck': 1
# 'strzok.': 1
# 'strongly': 1
# 'stronger': 2
# 'strong,': 1
# 'strong': 3
# 'strength.': 1
# 'streets.': 1
# 'street': 2
# 'strangling': 1
# 'strange."': 1
# 'strange.': 1
# 'straight': 2
# 'story.': 3
# 'story,': 4
# 'story': 3
# 'storms.': 1
# 'storm,': 1
# 'storm': 2
# 'stories': 1
# 'stops': 1
# 'stopped': 4
# 'stop.': 1
# 'stop': 4
# 'stone': 2
# 'stoltenberg,': 1
# 'stoltenberg': 1
# 'stocks."': 1
# 'stocks.': 1
# 'stocks': 1
# 'stock.': 2
# 'stock': 2
# 'still': 2
# 'stick': 2
# 'stephanopoulos,': 1
# 'steel.': 1
# 'steel': 6
# 'steam': 1
# 'stealth.': 2
# 'steal': 1
# 'stay': 1
# 'states."': 1
# 'states.': 1
# 'states,': 5
# 'states': 6
# 'statements,': 1
# 'statement,': 4
# 'statement': 5
# 'state.': 2
# 'state,': 3
# 'state': 3
# 'starting': 1
# 'started,': 1
# 'started': 7
# 'start.': 1
# 'start,': 1
# 'start': 2
# 'stars': 1
# 'star.': 1
# 'standpoint': 1
# 'standing,': 1
# 'standing': 2
# 'standards': 1
# 'stand': 3
# 'stamped': 1
# 'stake': 1
# 'stage.': 1
# 'stage,': 1
# 'stage': 2
# 'stadiums.': 1
# 'stadiums,': 1
# 'stadium': 2
# 'stacked,': 1
# 'stabbing': 1
# 'stabbed': 1
# 'spy': 1
# 'spoken': 1
# 'spoke': 2
# 'spoiled?': 1
# 'spiteful': 1
# 'spent.': 1
# 'spent': 2
# 'spending': 4
# 'spend': 3
# 'speed': 1
# 'speeches.': 1
# 'speeches,': 1
# 'speech?': 1
# 'speech,': 3
# 'speech': 3
# 'special.': 1
# 'speaking.': 1
# 'speaker,': 1
# 'speak.': 1
# 'speak': 2
# 'space': 2
# 'sovereignty': 1
# 'south.': 1
# 'south': 4
# 'sounds': 3
# 'sort': 1
# 'sorry,': 1
# 'sorry': 2
# 'soon,': 1
# 'soon': 2
# 'son's': 1
# 'son': 3
# 'some…': 1
# 'sometimes': 2
# 'something.': 3
# 'something,': 2
# 'something': 3
# 'someplace,': 1
# 'someplace': 1
# 'someday': 1
# 'somebody,': 2
# 'somebody's': 1
# 'somebody': 6
# 'some': 21
# 'socialist': 1
# 'socialism,': 1
# 'so."': 1
# 'so.': 3
# 'so,': 3
# 'so': 142
# 'smart,': 1
# 'smart': 1
# 'smaller.': 1
# 'smaller': 2
# 'small?"': 1
# 'small': 1
# 'slob.': 2
# 'sleepy': 2
# 'sleep.': 1
# 'sixth': 1
# 'six': 1
# 'situations.': 1
# 'sitting': 2
# 'sits.': 1
# 'sit': 2
# 'sir."': 6
# 'sir.': 5
# 'sir,': 3
# 'sinks,': 2
# 'sink,': 1
# 'sink': 1
# 'sinister': 1
# 'single': 3
# 'sincere,': 1
# 'since': 3
# 'simple.': 3
# 'simple,': 2
# 'signs.': 1
# 'signs': 1
# 'signed,': 1
# 'sign': 3
# 'side.': 1
# 'side,': 1
# 'sick.': 1
# 'sick,': 1
# 'sick': 1
# 'shut': 2
# 'showing': 1
# 'showers.': 1
# 'showers,': 2
# 'shower?': 1
# 'shower,': 2
# 'show,': 1
# 'show': 3
# 'shouldn't': 2
# 'shoulders': 1
# 'should': 13
# 'shortly.': 1
# 'short': 3
# 'shooting': 1
# 'shoot': 1
# 'ships.': 1
# 'ships': 2
# 'ship.': 1
# 'shinzo,': 1
# 'sheriffs': 1
# 'she's': 12
# 'she'll': 1
# 'she': 36
# 'shape.': 1
# 'shame,': 1
# 'sewers.': 1
# 'seven,': 1
# 'seven': 2
# 'setting': 1
# 'set': 5
# 'service,': 1
# 'seriously,': 1
# 'seriously': 1
# 'sentence': 1
# 'sent': 3
# 'sense?': 1
# 'sense,': 1
# 'sending': 1
# 'send': 2
# 'senators,': 1
# 'senate.': 1
# 'senate,': 1
# 'senate': 1
# 'sell': 4
# 'selfish,': 1
# 'select': 1
# 'sees': 1
# 'seen.': 1
# 'seen': 10
# 'seeing': 3
# 'see?': 1
# 'see.': 1
# 'see,': 5
# 'see': 36
# 'security': 1
# 'secure': 1
# 'secretary': 2
# 'secret.': 1
# 'secret': 1
# 'second': 2
# 'seats.': 1
# 'seats,': 2
# 'seats': 2
# 'seat.': 1
# 'seat': 3
# 'season.': 1
# 'season,': 1
# 'sean': 1
# 'screwed': 1
# 'screen,': 1
# 'screams': 1
# 'screaming,': 1
# 'science': 1
# 'schumer.': 2
# 'schumer,': 1
# 'schumer': 3
# 'schools.': 2
# 'schools,': 1
# 'schiff."': 1
# 'schiff.': 1
# 'schiff,': 1
# 'schiff': 2
# 'scheme,': 1
# 'scandal,': 1
# 'scams,': 1
# 'scale': 1
# 'says,': 5
# 'says': 1
# 'sayonara.': 1
# 'saying.': 1
# 'saying,': 4
# 'saying': 5
# 'say?': 1
# 'say.': 3
# 'say,': 42
# 'say': 46
# 'saw': 6
# 'savings,': 3
# 'saving': 1
# 'saved.': 1
# 'saved': 1
# 'save': 1
# 'sanitary,': 1
# 'sane,': 1
# 'sandusky,': 1
# 'sanctuary': 10
# 'sanctity': 1
# 'san.': 1
# 'san': 2
# 'same': 7
# 'salvador.': 1
# 'salvador,': 1
# 'salesman.': 2
# 'salesman,': 2
# 'salaries.': 1
# 'said.': 3
# 'said,': 101
# 'said': 38
# 'safety,': 2
# 'safety': 1
# 'safe,': 1
# 'safe': 2
# 'sadistically': 1
# 'sad,': 1
# 'sad': 1
# 'sacred': 4
# 'russia?"': 1
# 'russia.': 1
# 'russia': 1
# 'rush': 1
# 'run…': 1
# 'running,': 1
# 'running': 1
# 'run.': 2
# 'run,': 1
# 'run': 2
# 'row?': 1
# 'round': 4
# 'rotunda': 1
# 'rose': 1
# 'room.': 1
# 'room': 1
# 'ronna?': 2
# 'ronna,': 1
# 'ronna': 3
# 'ron': 1
# 'rocket': 1
# 'rock': 1
# 'roam': 1
# 'roads': 1
# 'road.': 1
# 'rnc?"': 1
# 'ripping': 3
# 'ripped': 2
# 'rip': 3
# 'riot…': 1
# 'riots.': 1
# 'righteous.': 3
# 'right?"': 1
# 'right?': 52
# 'right."': 1
# 'right.': 7
# 'right,': 1
# 'right': 31
# 'ridiculous': 1
# 'ride': 1
# 'rid': 3
# 'richard': 1
# 'rich': 1
# 'returning': 1
# 'results': 1
# 'resulting': 1
# 'result': 1
# 'restrictions.': 1
# 'respirator,': 1
# 'respected.': 1
# 'respected,': 1
# 'respected': 2
# 'respect': 3
# 'reputations.': 1
# 'republicans."': 1
# 'republicans.': 1
# 'republicans,': 1
# 'republicans': 7
# 'republican.': 1
# 'republican,': 1
# 'republican': 11
# 'republic': 1
# 'reports?': 1
# 'reports': 2
# 'report.': 1
# 'report,': 3
# 'repeatedly': 1
# 'repeat': 1
# 'rent,': 1
# 'remember,': 4
# 'remember': 23
# 'religious': 1
# 'religion,': 2
# 'released': 1
# 'release.': 1
# 'release': 2
# 'relaxing."': 1
# 'regulations': 3
# 'regulation': 2
# 'registered,': 1
# 'reg': 1
# 'refused': 1
# 'refer': 1
# 'recruit': 1
# 'records.': 1
# 'records': 4
# 'record.': 1
# 'record': 3
# 'recognize': 2
# 'recession."': 2
# 'recently,': 1
# 'recently': 2
# 'receive': 1
# 'recanted.': 1
# 'recant,': 1
# 'rebuilding': 2
# 'reasons.': 1
# 'reasons': 1
# 'reason,': 2
# 'reason': 1
# 'really?': 1
# 'really,': 3
# 'really': 16
# 'real': 5
# 'read': 9
# 'reach': 1
# 'ratings.': 1
# 'ratings': 1
# 'rather': 1
# 'rapids.': 2
# 'rapids,': 1
# 'ran,': 2
# 'ran': 2
# 'rally?': 1
# 'rally,': 1
# 'rally': 1
# 'rallies.': 1
# 'rallies': 2
# 'raised,': 1
# 'raise': 4
# 'rains': 1
# 'rage.': 1
# 'radical': 2
# 'race,': 1
# 'quos?': 1
# 'quiet': 1
# 'quid': 1
# 'quick': 1
# 'question?': 1
# 'question."': 1
# 'question,': 2
# 'quarter': 1
# 'quality': 1
# 'qualify.': 1
# 'putting': 1
# 'put': 11
# 'pushing': 1
# 'pursuit': 1
# 'purely': 1
# 'publicity': 1
# 'provided': 1
# 'proven': 1
# 'proudly': 1
# 'proud': 6
# 'protesters': 1
# 'protections': 1
# 'protecting': 1
# 'protect': 7
# 'prosperity.': 1
# 'prosecutors': 1
# 'prosecutor.': 1
# 'prosecutor': 1
# 'proof?"': 1
# 'proof.': 1
# 'proof': 1
# 'pronouncing': 1
# 'pronounce': 2
# 'promised.': 1
# 'promised,': 2
# 'promise.': 1
# 'prohibitive.': 1
# 'prohibit': 1
# 'progressive': 1
# 'profuse': 1
# 'professionally?'': 1
# 'products,': 2
# 'product.': 2
# 'product,': 1
# 'producer': 1
# 'produced': 1
# 'produce': 1
# 'process.': 2
# 'process,': 1
# 'proceeding': 1
# 'problems': 3
# 'problem.': 2
# 'problem': 3
# 'probably': 5
# 'pro.': 2
# 'pro': 1
# 'private,': 1
# 'privacy,': 1
# 'prisons': 1
# 'prisoner': 1
# 'prime': 3
# 'primary,': 1
# 'pricing,': 1
# 'prices.': 2
# 'prices,': 1
# 'prices': 6
# 'price': 1
# 'previous': 6
# 'pretty': 5
# 'pretend': 1
# 'pressure.': 1
# 'pressure,': 1
# 'pressure': 3
# 'press': 5
# 'presidents,': 1
# 'president?"': 2
# 'president."': 1
# 'president.': 6
# 'president,"': 1
# 'president,': 5
# 'president': 23
# 'present': 1
# 'pres,': 1
# 'preexisting': 2
# 'powerful': 4
# 'powered': 1
# 'power.': 1
# 'power': 3
# 'poverty': 4
# 'pours': 1
# 'pouring': 1
# 'potholes.': 2
# 'potholes': 1
# 'post,': 1
# 'possible.': 1
# 'positive': 1
# 'position.': 1
# 'popular,': 1
# 'popular': 1
# 'poor,': 1
# 'pond.': 1
# 'pompous.': 1
# 'polluted': 1
# 'polls.': 3
# 'polls': 4
# 'polling': 3
# 'poll,': 1
# 'politics.': 1
# 'politicians.': 1
# 'politicians,': 2
# 'politicians': 2
# 'politician,': 1
# 'politician': 1
# 'politically': 1
# 'political': 2
# 'policy?': 1
# 'policy!': 1
# 'policy': 2
# 'policies,': 1
# 'policies': 1
# 'policeman.': 1
# 'police': 2
# 'point': 2
# 'pockets.': 1
# 'pocahontas.': 1
# 'pocahontas,': 1
# 'pocahontas': 1
# 'pneumonia."': 1
# 'pledged,': 1
# 'pledged': 1
# 'please."': 1
# 'please.': 1
# 'please': 4
# 'playing': 2
# 'platform."': 1
# 'platform.': 1
# 'platform': 1
# 'plants.': 2
# 'plants': 2
# 'plant': 4
# 'plans.': 1
# 'planet': 2
# 'planes.': 1
# 'planes,': 1
# 'planes': 3
# 'plane?"': 1
# 'plan."': 1
# 'places.': 2
# 'places,': 2
# 'places': 1
# 'place.': 3
# 'place,': 1
# 'place': 6
# 'pinocchio.': 3
# 'pinocchio,"': 1
# 'pile': 1
# 'pieces': 1
# 'piece': 2
# 'picked': 1
# 'pick': 1
# 'physicians.': 1
# 'phrase,': 1
# 'phony.': 1
# 'phony,': 2
# 'phony': 3
# 'phone,': 2
# 'phone': 1
# 'phenomenal.': 2
# 'phase': 1
# 'peter?': 1
# 'peter.': 1
# 'peter,': 1
# 'peter': 1
# 'pete.': 3
# 'pete,': 2
# 'pete!': 1
# 'perversion.': 1
# 'perversion,': 1
# 'personal,': 1
# 'personal': 1
# 'person.': 1
# 'person,': 2
# 'person': 4
# 'period,': 1
# 'period': 8
# 'performance': 1
# 'perfectly,': 1
# 'perfect."': 1
# 'perfect.': 2
# 'percentage.': 1
# 'percentage,': 2
# 'percent.': 1
# 'people…': 1
# 'people."': 1
# 'people.': 25
# 'people,': 19
# 'people': 66
# 'penny': 1
# 'pennsylvania,': 2
# 'pence.': 1
# 'pelosi,': 1
# 'pelosi's': 1
# 'pelosi': 8
# 'paying': 5
# 'pay?': 1
# 'pay.': 2
# 'pay': 8
# 'patrol': 2
# 'patriots.': 1
# 'patriots': 2
# 'patriotic': 1
# 'patients': 1
# 'pathological': 1
# 'passe.': 1
# 'pass': 1
# 'party.': 2
# 'party,': 3
# 'party's': 1
# 'party': 8
# 'parts': 1
# 'partnership.': 1
# 'partisan': 3
# 'particular,': 1
# 'part': 2
# 'park': 2
# 'paris': 3
# 'parents': 1
# 'painful.': 1
# 'painful': 1
# 'pain.': 1
# 'pain,': 1
# 'pain': 2
# 'paid': 1
# 'page,': 1
# 'packed.': 1
# 'packed': 1
# 'pacific': 3
# 'owned': 1
# 'own-': 1
# 'own,': 1
# 'own': 5
# 'overwhelmingly,': 1
# 'over."': 2
# 'over': 23
# 'outside.': 1
# 'outside,': 2
# 'outside': 2
# 'outrageous': 1
# 'out?': 1
# 'out.': 8
# 'out,': 8
# 'out': 30
# 'our': 59
# 'ought': 5
# 'other': 20
# 'orion': 1
# 'orange?"': 1
# 'or': 27
# 'opens,': 1
# 'openings.': 1
# 'opening': 2
# 'opened': 1
# 'open': 5
# 'onto': 1
# 'only': 8
# 'ones.': 1
# 'ones': 6
# 'one."': 1
# 'one.': 5
# 'one,': 4
# 'one': 58
# 'once': 2
# 'on?': 2
# 'on.': 1
# 'on,': 3
# 'on': 68
# 'older': 2
# 'old.': 3
# 'old': 4
# 'okay?"': 1
# 'okay?': 16
# 'okay.': 10
# 'okay,': 8
# 'oil': 3
# 'oh."': 1
# 'oh.': 1
# 'oh,': 9
# 'oh': 4
# 'officers': 1
# 'office.': 6
# 'office,': 1
# 'office': 1
# 'off.': 2
# 'off,': 2
# 'off': 11
# 'of.': 2
# 'of,': 1
# 'of': 308
# 'odd': 1
# 'ocean': 2
# 'obviously': 1
# 'obstructing': 1
# 'obsessed': 1
# 'obama…"': 1
# 'obamacare.': 1
# 'obama?': 2
# 'obama."': 1
# 'obama.': 5
# 'obama,': 4
# 'obama': 3
# 'oath': 1
# 'o'clock.': 1
# 'o'clock': 2
# 'numbers.': 2
# 'numbers,': 1
# 'numbers': 3
# 'number,': 1
# 'number': 9
# 'nullify': 1
# 'nullification': 1
# 'nuggets.': 1
# 'nuggets,': 1
# 'nuclear': 2
# 'now."': 1
# 'now.': 9
# 'now,': 11
# 'now': 50
# 'november.': 1
# 'november,': 1
# 'november': 3
# 'noticed': 1
# 'notice?': 1
# 'notice,': 1
# 'notice': 2
# 'nothing.': 4
# 'nothing': 11
# 'not."': 1
# 'not,': 4
# 'not': 65
# 'north': 1
# 'nor': 1
# 'nope,': 1
# 'nonsense.': 1
# 'non-monetary': 1
# 'nobody.': 1
# 'nobody's': 3
# 'nobody': 13
# 'no."': 1
# 'no.': 2
# 'no,"': 1
# 'no,': 21
# 'no!': 1
# 'no': 23
# 'nixon,': 1
# 'nine,': 1
# 'nine': 1
# 'nights': 1
# 'night.': 3
# 'night,': 1
# 'nicest': 1
# 'nicer.': 1
# 'nice,': 1
# 'nice': 1
# 'next': 2
# 'newspapers': 2
# 'newspaper.': 1
# 'newspaper': 1
# 'news.': 1
# 'news,': 2
# 'news': 3
# 'newman.': 1
# 'newer': 1
# 'new': 14
# 'never.': 1
# 'never,': 3
# 'never': 43
# 'nest.': 1
# 'nest': 1
# 'nervous': 1
# 'negotiated': 2
# 'negative': 3
# 'need…': 1
# 'needles': 1
# 'needed': 1
# 'need': 15
# 'nearest': 1
# 'nba': 1
# 'natural': 1
# 'nato.': 2
# 'nato': 3
# 'nations,': 1
# 'national': 1
# 'nation.': 5
# 'nation,': 1
# 'nation's': 1
# 'nation': 1
# 'nancy': 5
# 'names.': 1
# 'name."': 1
# 'name.': 1
# 'nah,': 1
# 'nafta,': 1
# 'my': 30
# 'mustang': 1
# 'must've': 1
# 'must': 3
# 'murders': 1
# 'murderer,': 1
# 'murder': 2
# 'multiply': 1
# 'muller': 2
# 'mueller.': 1
# 'mueller': 1
# 'much.': 6
# 'much,': 8
# 'much': 20
# 'msnbc.': 1
# 'msnbc,': 1
# 'ms13': 2
# 'moving.': 1
# 'movie': 1
# 'movement,': 1
# 'moved': 2
# 'motto': 1
# 'motown,': 1
# 'motors,': 2
# 'motors': 2
# 'motor': 2
# 'mother's': 1
# 'mother': 1
# 'most.': 2
# 'most,': 1
# 'most': 14
# 'morning.': 1
# 'morning': 1
# 'more.': 6
# 'more,': 2
# 'more': 42
# 'months,': 5
# 'months': 6
# 'month,': 1
# 'money."': 1
# 'money.': 4
# 'money,': 2
# 'money': 15
# 'moment': 1
# 'mom.': 1
# 'miss': 1
# 'miracle': 1
# 'minutes': 1
# 'minute.': 1
# 'minute,': 1
# 'minute': 1
# 'ministers,': 1
# 'minister': 2
# 'mine': 1
# 'mills.': 2
# 'mills': 1
# 'millions': 4
# 'million."': 1
# 'million.': 1
# 'million,': 2
# 'million': 9
# 'military.': 2
# 'military,': 4
# 'military': 2
# 'militarily,': 1
# 'miles,': 1
# 'miles': 1
# 'might.': 1
# 'might,': 1
# 'might': 5
# 'midwest.': 1
# 'middle.': 1
# 'middle': 1
# 'mid': 1
# 'mics.': 1
# 'michigan?"': 2
# 'michigan?': 1
# 'michigan."': 3
# 'michigan.': 20
# 'michigan,': 4
# 'michigan's': 1
# 'michigan"?': 1
# 'michigan': 19
# 'michelle': 1
# 'mic.': 1
# 'mic,': 1
# 'mexico.': 2
# 'mexico,': 2
# 'mexico': 4
# 'met.': 1
# 'merry': 5
# 'merit.': 1
# 'merit,': 1
# 'mercy': 1
# 'mentioned': 2
# 'mention': 5
# 'men.': 1
# 'men,': 1
# 'men': 1
# 'members.': 1
# 'member,': 1
# 'meetings.': 1
# 'medicine.': 1
# 'medical': 2
# 'median': 1
# 'media': 1
# 'meantime,': 1
# 'meant.': 1
# 'means.': 1
# 'means': 4
# 'meaning': 1
# 'meanest': 1
# 'mean,': 14
# 'mean': 7
# 'me?"': 1
# 'me?': 1
# 'me."': 2
# 'me.': 15
# 'me,': 20
# 'me!': 1
# 'me': 34
# 'mcdaniel,': 2
# 'mcdaniel': 1
# 'mayor': 6
# 'maybe.': 1
# 'maybe,': 1
# 'maybe': 9
# 'may': 5
# 'massive,': 1
# 'massive': 3
# 'markets.': 1
# 'market': 1
# 'mark': 1
# 'march': 1
# 'many,': 5
# 'many': 24
# 'manufacturing?': 1
# 'manufacturing': 7
# 'mankind': 1
# 'maniacs': 2
# 'manhattan.': 2
# 'manhattan,': 1
# 'mandate,': 1
# 'mandate': 1
# 'manager.': 1
# 'man': 11
# 'maloney.': 2
# 'maloney,': 1
# 'male': 1
# 'making': 5
# 'makes': 6
# 'make': 18
# 'majority,': 1
# 'major': 2
# 'magic': 2
# 'mafia': 2
# 'made…': 2
# 'made.': 3
# 'made,': 2
# 'made': 18
# 'machines.': 1
# 'machinery': 1
# 'lying?"': 1
# 'lucky.': 1
# 'lucky,"': 1
# 'lucky': 2
# 'loyal': 1
# 'lowest': 2
# 'lowering': 3
# 'loves': 2
# 'lover,': 1
# 'loved': 4
# 'love."': 1
# 'love': 32
# 'lousy': 2
# 'loud': 1
# 'lottery?': 1
# 'lots': 3
# 'lot.': 2
# 'lot,': 1
# 'lot': 36
# 'lost': 1
# 'loses,': 1
# 'loser.': 2
# 'lose.': 2
# 'lose,': 1
# 'lose': 8
# 'los': 1
# 'loophole.': 1
# 'looks': 4
# 'looking.': 1
# 'looking': 6
# 'looked': 3
# 'look,': 14
# 'look': 22
# 'longterm,': 1
# 'long,': 1
# 'long': 15
# 'lock': 3
# 'local': 2
# 'lobby?"': 1
# 'lobby': 1
# 'lobbies.': 1
# 'loan.': 1
# 'loaded': 1
# 'lives': 2
# 'live': 1
# 'little,': 1
# 'little': 19
# 'listening': 1
# 'listen,': 1
# 'listen': 2
# 'list': 1
# 'lisa.': 1
# 'lisa': 1
# 'line.': 1
# 'line': 1
# 'lincoln.': 1
# 'lincoln': 1
# 'limbaugh': 1
# 'likes': 1
# 'liked': 3
# 'like?': 1
# 'like,': 3
# 'like': 69
# 'lightly': 1
# 'light?"': 1
# 'light.': 3
# 'light,': 1
# 'light': 8
# 'lift': 1
# 'life.': 4
# 'life,': 3
# 'life': 1
# 'lied': 2
# 'liberty,': 1
# 'liar.': 2
# 'liar!': 1
# 'liability."': 1
# 'liability.': 1
# 'liability,': 2
# 'levels,': 1
# 'levels': 1
# 'level,': 1
# 'level': 1
# 'letter': 3
# 'let's': 8
# 'let': 16
# 'less.': 1
# 'less': 7
# 'legislators': 1
# 'left,': 1
# 'left': 5
# 'lee?': 2
# 'lee.': 2
# 'lee,': 3
# 'lee': 1
# 'leaves': 1
# 'leave?"': 1
# 'leave.': 2
# 'leave': 3
# 'least': 1
# 'learned': 1
# 'learn': 1
# 'leading.': 1
# 'leaders.': 2
# 'leaders,': 1
# 'leader': 1
# 'lawn,': 2
# 'lawmakers': 1
# 'lawless,': 1
# 'lawful': 1
# 'law.': 1
# 'law': 1
# 'laura': 2
# 'later': 1
# 'late': 3
# 'last,': 1
# 'last': 16
# 'largest': 1
# 'largely': 1
# 'land.': 3
# 'land,': 1
# 'land': 2
# 'lady,': 2
# 'lady': 2
# 'ladies': 1
# 'labs,': 1
# 'labor.': 2
# 'labor': 2
# 'korea.': 2
# 'korea,': 2
# 'knows.': 1
# 'known': 2
# 'know?"': 1
# 'know?': 4
# 'know.': 6
# 'know,': 27
# 'know': 99
# 'knocking': 1
# 'knocked': 1
# 'knife.': 1
# 'knife': 2
# 'knew': 3
# 'kitchen': 1
# 'kiss': 1
# 'kind,': 2
# 'kind': 1
# 'killing': 1
# 'killer.': 1
# 'killer': 1
# 'killed': 1
# 'kids': 1
# 'kernel,': 1
# 'kept.': 1
# 'kept': 1
# 'kent': 2
# 'kellogg': 1
# 'keeping': 1
# 'keep': 6
# 'kavanaugh,': 1
# 'kavanaugh': 1
# 'justices,': 3
# 'justices': 1
# 'justice.': 2
# 'justice': 1
# 'just,': 1
# 'just': 52
# 'jurisdiction': 1
# 'june,': 1
# 'judges.': 2
# 'judges,': 1
# 'judges': 5
# 'judge': 1
# 'journey?': 1
# 'journey."': 1
# 'journey.': 1
# 'journey,': 2
# 'journal.': 1
# 'journal': 1
# 'joined': 1
# 'john': 1
# 'joe': 2
# 'jobs."': 1
# 'jobs.': 7
# 'jobs,': 6
# 'jobs': 8
# 'job?': 2
# 'job.': 9
# 'job-killing': 1
# 'job,': 3
# 'job': 9
# 'jets': 1
# 'jerusalem.': 1
# 'jefferson': 1
# 'japanese.': 1
# 'japanese': 1
# 'japan.': 2
# 'japan,': 3
# 'japan': 1
# 'james': 1
# 'jails': 1
# 'jail.': 1
# 'jail': 1
# 'i…': 1
# 'it…': 1
# 'its': 1
# 'it?"': 1
# 'it?': 7
# 'it."': 7
# 'it.': 68
# 'it,': 28
# 'it's,': 1
# 'it's': 140
# 'it"': 1
# 'it': 164
# 'israeli': 1
# 'israel's': 1
# 'isn't': 2
# 'is?': 3
# 'is.': 8
# 'is,': 7
# 'is': 100
# 'irs': 1
# 'iran,': 1
# 'iran': 2
# 'in…': 1
# 'invoke': 1
# 'investors.': 1
# 'investments': 1
# 'investment': 2
# 'investing': 1
# 'invested,': 1
# 'invested': 1
# 'invented': 1
# 'invalid': 1
# 'into': 28
# 'internet.': 1
# 'interfering': 1
# 'interesting': 1
# 'interest': 1
# 'intent': 1
# 'insurance': 5
# 'insulting': 1
# 'instruction,': 1
# 'instinct.': 2
# 'instinct': 2
# 'instead,': 1
# 'instead': 2
# 'inspiring.': 2
# 'inspector': 2
# 'inside.': 1
# 'insane': 1
# 'innocent': 1
# 'ingram': 1
# 'infrastructure': 1
# 'industry.': 2
# 'industry,': 2
# 'industry': 3
# 'individual': 2
# 'independence': 1
# 'incredible.': 3
# 'incredible,': 1
# 'incredible': 10
# 'increase.': 1
# 'income': 1
# 'including': 4
# 'includes': 1
# 'incensed,': 1
# 'in.': 4
# 'in,': 9
# 'in': 196
# 'improve': 1
# 'important.': 1
# 'important': 2
# 'impeachment,': 6
# 'impeachment': 5
# 'impeached.': 3
# 'impeached,': 2
# 'impeach.': 1
# 'impeach,': 1
# 'impeach': 12
# 'immunity,': 1
# 'immigration.': 1
# 'immigration,': 1
# 'immigration': 1
# 'immediately': 1
# 'imagine?': 2
# 'imagine,': 1
# 'illegality.': 1
# 'illegal': 4
# 'ill.': 1
# 'ill,': 2
# 'ig,': 1
# 'if': 62
# 'identical': 2
# 'ideally': 1
# 'idea."': 1
# 'idea': 2
# 'ice.': 1
# 'i've': 19
# 'i'm': 51
# 'i'll': 21
# 'i'd': 3
# 'i': 491
# 'husband': 1
# 'hurt': 6
# 'hunts,': 1
# 'hunt.': 1
# 'hunt': 1
# 'hundreds': 2
# 'hundred': 3
# 'human': 2
# 'how's': 3
# 'how': 33
# 'houses': 1
# 'households': 1
# 'house.': 3
# 'house,': 3
# 'house': 4
# 'hospital.': 1
# 'hospital': 1
# 'horrible.': 2
# 'horrible,': 4
# 'horrible': 9
# 'hornet's': 1
# 'hope': 4
# 'honored.': 1
# 'honored': 1
# 'honor.': 1
# 'honor,': 1
# 'honor': 1
# 'honduras,': 2
# 'homes,': 1
# 'homes': 1
# 'homeless': 2
# 'home.': 2
# 'home,': 1
# 'home': 6
# 'hollywood."': 1
# 'holding': 1
# 'hold': 1
# 'hoaxes,': 1
# 'hoax.': 2
# 'hit': 1
# 'history.': 2
# 'history,': 1
# 'history': 12
# 'historically': 2
# 'historical.': 1
# 'hispanic': 1
# 'his.': 1
# 'his': 8
# 'him?': 2
# 'him.': 9
# 'him,': 8
# 'him': 27
# 'hillary?': 1
# 'hillary.': 1
# 'hillary,': 3
# 'hillary': 3
# 'highly': 1
# 'higher': 2
# 'high': 2
# 'hid': 1
# 'heroes': 1
# 'here?': 4
# 'here.': 6
# 'here,': 7
# 'here's': 5
# 'here': 11
# 'her.': 3
# 'her,': 3
# 'her': 25
# 'henry': 1
# 'helps.': 1
# 'helps': 1
# 'helped,': 2
# 'helped': 1
# 'help.': 2
# 'help,': 2
# 'help': 6
# 'hell,': 1
# 'hell': 12
# 'heights.': 1
# 'hearing': 1
# 'heard.': 2
# 'heard': 8
# 'hear,': 1
# 'hear': 10
# 'healthcare.': 1
# 'healthcare': 4
# 'health': 1
# 'heads': 1
# 'headline': 3
# 'heading': 1
# 'head': 3
# 'he?': 1
# 'he,': 1
# 'he's': 38
# 'he'd': 4
# 'he': 109
# 'hazardous': 1
# 'having': 1
# 'have…': 1
# 'haven't': 2
# 'have?"': 1
# 'have.': 2
# 'have,': 1
# 'have': 186
# 'hatred': 2
# 'hates': 1
# 'haters,': 1
# 'hate': 4
# 'hasn't': 1
# 'has.': 1
# 'has': 21
# 'hardworking': 1
# 'hardly': 1
# 'harder': 2
# 'hard?"': 1
# 'hard': 3
# 'happy.': 2
# 'happy,': 3
# 'happy': 2
# 'happiest': 1
# 'happens?': 3
# 'happens.': 2
# 'happens,': 2
# 'happens': 3
# 'happening?': 1
# 'happening.': 3
# 'happening': 3
# 'happened?"': 1
# 'happened?': 5
# 'happened.': 3
# 'happened,': 1
# 'happened': 4
# 'happen?': 1
# 'happen.': 2
# 'happen,': 1
# 'hannity': 1
# 'handsome,': 1
# 'handsome': 1
# 'hands,': 1
# 'handled': 1
# 'handle': 1
# 'hand': 1
# 'half.': 1
# 'half': 4
# 'haleigh,': 1
# 'haleigh!': 1
# 'hairpieces.': 1
# 'hairpiece.': 1
# 'had.': 3
# 'had,': 2
# 'had': 57
# 'guys."': 1
# 'guys.': 4
# 'guys,': 4
# 'guys': 6
# 'guy?': 2
# 'guy.': 3
# 'guy,': 5
# 'guy's': 2
# 'guy': 10
# 'guns.': 1
# 'guns,': 3
# 'guns': 1
# 'gun': 1
# 'guilty.': 1
# 'guessing,': 1
# 'guatemala,': 2
# 'guarantee.': 1
# 'growth': 1
# 'grow': 1
# 'group.': 1
# 'group,': 3
# 'group': 9
# 'greats.': 1
# 'greatness': 1
# 'greatest…': 1
# 'greatest?': 1
# 'greatest.': 1
# 'greatest': 14
# 'greater': 1
# 'great?': 1
# 'great."': 1
# 'great.': 11
# 'great,"': 1
# 'great,': 5
# 'great': 58
# 'granted,': 1
# 'grandfather': 1
# 'grand': 3
# 'grab': 1
# 'governors': 1
# 'governor': 2
# 'government,': 1
# 'government': 1
# 'gotten': 2
# 'got': 47
# 'gorsuch.': 1
# 'gop': 1
# 'goodbye."': 1
# 'good."': 1
# 'good.': 7
# 'good,': 2
# 'good': 25
# 'gone.': 3
# 'gone': 1
# 'golem's': 1
# 'golden': 1
# 'golan': 1
# 'going,': 1
# 'going': 96
# 'goes,': 1
# 'goes': 6
# 'god.': 3
# 'god': 1
# 'go.': 3
# 'go,': 2
# 'go': 40
# 'glory': 1
# 'glorious': 1
# 'globalists.': 3
# 'globalists': 1
# 'giving': 8
# 'gives': 5
# 'give.': 1
# 'give': 20
# 'girls,': 1
# 'gift': 1
# 'getting': 11
# 'gets': 6
# 'get.': 1
# 'get,': 2
# 'get': 56
# 'gesture': 1
# 'germany.': 3
# 'germany,': 1
# 'germany': 1
# 'ger': 1
# 'george': 1
# 'gentlemen': 1
# 'geniuses': 1
# 'genius.': 1
# 'generations': 2
# 'generation.': 1
# 'generals': 1
# 'generally': 1
# 'general,': 1
# 'general': 11
# 'gave.': 1
# 'gave': 13
# 'gasping.': 1
# 'gasping': 1
# 'gasoline': 2
# 'gas.': 3
# 'gas,': 1
# 'gas': 4
# 'garbage.': 1
# 'garbage': 1
# 'gang': 1
# 'games.': 1
# 'gals': 1
# 'gains': 1
# 'gain."': 1
# 'funny,': 2
# 'funding': 2
# 'fun?': 1
# 'fun.': 1
# 'front': 4
# 'from,': 1
# 'from': 39
# 'friends': 2
# 'friend': 1
# 'free': 3
# 'frankly,': 4
# 'francisco,': 1
# 'francisco': 1
# 'france,': 2
# 'france': 1
# 'foxconn': 1
# 'four': 17
# 'founding,': 1
# 'founding': 2
# 'founders': 1
# 'forward': 1
# 'fortunately.': 1
# 'forms': 1
# 'forgotten': 3
# 'forgot': 1
# 'forget,': 3
# 'forget': 2
# 'forever.': 2
# 'foreigners': 1
# 'foreign': 4
# 'ford': 2
# 'forces,': 2
# 'force?': 1
# 'force.': 1
# 'force,': 1
# 'for?"': 1
# 'for?': 1
# 'for,': 1
# 'for': 100
# 'fools.': 1
# 'follow': 1
# 'folks.': 3
# 'folks,': 2
# 'folks!': 1
# 'folks': 1
# 'focused': 1
# 'focus': 1
# 'flows': 1
# 'florida.': 2
# 'florida,': 1
# 'floor.': 1
# 'floor,': 1
# 'flint?': 1
# 'flint.': 2
# 'flights."': 1
# 'flights,': 1
# 'flew': 2
# 'flags."': 1
# 'flag.': 1
# 'fixing': 2
# 'fixed.': 1
# 'fix': 1
# 'five': 5
# 'fit.': 1
# 'fisa': 2
# 'first': 23
# 'firing': 1
# 'fired': 1
# 'finished.': 3
# 'finished': 1
# 'finger': 2
# 'finest?': 1
# 'fine.': 3
# 'fine,': 1
# 'fine': 2
# 'finding': 1
# 'find': 1
# 'financial': 1
# 'finally': 5
# 'final': 1
# 'filth': 3
# 'fill': 3
# 'figured': 2
# 'fighting.': 2
# 'fighting': 3
# 'fighter': 1
# 'fight.': 2
# 'fight': 2
# 'field."': 1
# 'fictitious,': 1
# 'fiat-chrysler': 1
# 'few': 1
# 'female,': 1
# 'feel': 4
# 'fee.': 1
# 'federal': 2
# 'february': 1
# 'fda': 1
# 'fbi.': 1
# 'fbi': 3
# 'favor."': 2
# 'favor,': 4
# 'favor': 1
# 'fathers': 2
# 'father': 2
# 'fast': 1
# 'farmers.': 2
# 'farmers,': 1
# 'farmers': 3
# 'farm': 2
# 'far.': 3
# 'far': 3
# 'fantastic.': 1
# 'fantastic': 1
# 'fan': 3
# 'famous': 1
# 'family.': 3
# 'family,': 3
# 'family': 5
# 'families': 1
# 'fake.': 1
# 'fake': 12
# 'faith': 1
# 'fairness,"': 1
# 'fairness,': 2
# 'fairness': 1
# 'fair,': 2
# 'fair': 1
# 'factories,': 1
# 'factories': 2
# 'fact."': 1
# 'fact,"': 1
# 'fact,': 1
# 'fact': 2
# 'faced.': 1
# 'faced,': 1
# 'extreme': 2
# 'extraordinary': 1
# 'extra': 1
# 'extent': 1
# 'explosion,': 1
# 'explode?': 1
# 'experts': 1
# 'expensive,': 2
# 'expansions.': 1
# 'expanding': 2
# 'exonerated.': 2
# 'exerted': 2
# 'excuse.': 1
# 'exculpated': 1
# 'exciting.': 1
# 'except': 1
# 'exactly': 3
# 'ex-congressman': 1
# 'everything."': 1
# 'everything.': 4
# 'everything,': 1
# 'everything': 6
# 'everyone': 4
# 'everybody.': 4
# 'everybody's': 1
# 'everybody': 5
# 'every': 19
# 'ever.': 2
# 'ever,': 1
# 'ever': 45
# 'eventually': 1
# 'evenings': 1
# 'evening?': 1
# 'evening,': 1
# 'evening': 2
# 'even': 30
# 'europe.': 2
# 'eternity.': 1
# 'eternal': 1
# 'estate.': 1
# 'estate': 1
# 'especially': 3
# 'escalator.': 1
# 'escalator': 1
# 'eroding': 1
# 'era,': 1
# 'equipment': 3
# 'epidemic': 2
# 'envy': 1
# 'enthusiasm': 1
# 'ensuring': 1
# 'enough.': 2
# 'enough': 2
# 'enforcement.': 1
# 'energy.': 1
# 'energy,': 1
# 'energy': 2
# 'enemy': 1
# 'ending': 1
# 'ended': 7
# 'end': 6
# 'enact': 1
# 'empty': 2
# 'employment': 1
# 'employee': 1
# 'emergency': 2
# 'embassy': 1
# 'embarrassment': 1
# 'embarrassing.': 1
# 'else?': 1
# 'else.': 1
# 'else,': 1
# 'else': 2
# 'elite.': 4
# 'elite': 1
# 'eliminated': 2
# 'eliminate': 1
# 'electric.': 3
# 'electric': 3
# 'elections.': 1
# 'elections': 1
# 'election.': 2
# 'election,': 2
# 'election': 8
# 'elected,': 1
# 'elected': 3
# 'elect': 1
# 'el': 2
# 'either.': 2
# 'either': 1
# 'eight.': 2
# 'eight-years,': 1
# 'eight,': 1
# 'eight': 10
# 'egregious': 1
# 'efforts': 1
# 'edge."': 1
# 'edge,"': 1
# 'edge': 3
# 'economy…"': 1
# 'economy.': 2
# 'economy,': 2
# 'economy's': 1
# 'economy': 5
# 'economies,': 1
# 'easy?': 1
# 'easy.': 2
# 'easy,': 1
# 'east': 1
# 'easily.': 1
# 'easier': 1
# 'earth.': 1
# 'earth,': 1
# 'early.': 1
# 'early,': 1
# 'early': 2
# 'earlier': 1
# 'e.': 1
# 'dying.': 3
# 'dying,': 1
# 'dying': 1
# 'duty': 1
# 'dump?': 1
# 'dump.': 1
# 'dump': 1
# 'due': 1
# 'drugs': 2
# 'drug,': 1
# 'drug': 6
# 'drops': 1
# 'drive,': 1
# 'drive': 2
# 'drip.': 1
# 'dream.': 1
# 'draining': 1
# 'drain.': 1
# 'downturn.': 1
# 'downstairs,': 1
# 'down."': 2
# 'down.': 9
# 'down,': 2
# 'down!': 1
# 'down': 12
# 'dossier.': 1
# 'dossier,': 2
# 'dossier': 1
# 'door': 1
# 'done?': 2
# 'done."': 1
# 'done.': 4
# 'done,': 3
# 'done': 21
# 'don't…': 1
# 'don't.': 2
# 'don't': 118
# 'dollars,': 2
# 'dollars': 8
# 'dollar': 2
# 'doing?': 1
# 'doing."': 1
# 'doing.': 4
# 'doing,': 2
# 'doing': 41
# 'doesn't': 10
# 'does,': 1
# 'does': 11
# 'document,': 1
# 'doctors,': 1
# 'doctor.': 2
# 'doctor,': 1
# 'do?': 5
# 'do.': 10
# 'do,': 5
# 'do': 106
# 'district': 3
# 'disproven,': 1
# 'display': 1
# 'dishwashers.': 2
# 'dishwashers,': 1
# 'dishwasher,': 2
# 'dishonesty.': 1
# 'dishonesty,': 1
# 'dishonest': 6
# 'dishes.': 1
# 'disgusting': 1
# 'disgrace.': 4
# 'disgrace,': 2
# 'diseases': 1
# 'disdain': 1
# 'discussing…': 1
# 'disaster,': 1
# 'disaster': 1
# 'disappointing.': 1
# 'directly': 2
# 'dingell?': 1
# 'dingell.': 1
# 'dingell,': 3
# 'dingell': 1
# 'dignity,': 1
# 'dignity': 1
# 'different,': 1
# 'different': 4
# 'die.': 1
# 'didn't."': 2
# 'didn't,': 1
# 'didn't': 38
# 'did.': 5
# 'did,': 2
# 'did': 45
# 'dictators,': 1
# 'devotion,': 1
# 'detroit': 2
# 'destroy': 2
# 'desantis,': 1
# 'dershowitz,': 1
# 'depressed,': 1
# 'depraved': 1
# 'deportations': 1
# 'depleted.': 2
# 'dependence': 1
# 'denouncing': 1
# 'democrats.': 3
# 'democrats,': 3
# 'democrats'': 1
# 'democrats': 17
# 'democrat,': 2
# 'democrat': 7
# 'democracy.': 2
# 'delinquent': 1
# 'deliberately': 1
# 'definitely': 1
# 'deficits.': 2
# 'deficits': 1
# 'deficit.': 1
# 'defense,': 1
# 'defense': 2
# 'defending': 1
# 'defend': 2
# 'deep': 1
# 'declaring': 2
# 'decided': 1
# 'decades': 2
# 'debbie': 1
# 'debates.': 2
# 'debates': 3
# 'debate?': 1
# 'debate': 1
# 'death,': 1
# 'death': 2
# 'dealt': 1
# 'deals.': 2
# 'deals,': 1
# 'deals': 4
# 'dealing': 2
# 'deal.': 12
# 'deal,': 6
# 'deal's': 1
# 'deal': 12
# 'deadly': 1
# 'days,': 1
# 'days': 2
# 'day?': 1
# 'day.': 1
# 'day,': 2
# 'day': 6
# 'data': 1
# 'dark,': 1
# 'dark': 1
# 'dare': 1
# 'dangerous,': 1
# 'dangerous': 2
# 'danger': 1
# 'damn': 4
# 'dairy': 1
# 'd.': 1
# 'cuts.': 1
# 'cut': 2
# 'currency': 1
# 'cures': 1
# 'crying': 2
# 'crummy': 1
# 'crowds.': 4
# 'crowds': 4
# 'crowd.': 2
# 'crowd,': 1
# 'crowd': 3
# 'crossings': 1
# 'crooked?': 1
# 'crooked,': 2
# 'crooked': 6
# 'criminal': 4
# 'crimes': 1
# 'crime.': 4
# 'crime,"': 1
# 'crime,': 1
# 'crime!': 2
# 'crime': 1
# 'creek,': 2
# 'credit,': 1
# 'credit': 1
# 'creating': 2
# 'created': 3
# 'create': 1
# 'crazy.': 8
# 'crazy,': 1
# 'crazy': 7
# 'crashing.': 1
# 'crashed.': 1
# 'crap': 1
# 'cox.': 1
# 'coverage': 1
# 'courts': 1
# 'court.': 4
# 'court,': 1
# 'court': 5
# 'course,': 1
# 'couple': 11
# 'county?': 1
# 'county,': 1
# 'country."': 2
# 'country.': 19
# 'country,"': 1
# 'country,': 11
# 'country's': 1
# 'country!': 1
# 'country': 13
# 'countries.': 2
# 'countries,': 4
# 'countries': 7
# 'couldn't': 3
# 'could."': 1
# 'could've.': 1
# 'could've': 1
# 'could': 32
# 'cost."': 1
# 'cost': 2
# 'corruption.': 2
# 'corrupt': 2
# 'correct': 2
# 'convicted': 2
# 'conversation,': 1
# 'convention': 1
# 'contributor': 1
# 'contributions': 2
# 'continue': 1
# 'contempt': 1
# 'consumer': 1
# 'consumed': 1
# 'construction': 1
# 'constitution."': 2
# 'constitution.': 1
# 'constitution': 2
# 'considered': 1
# 'consider': 2
# 'congresswoman': 1
# 'congresspeople,': 1
# 'congressmen,': 2
# 'congressmen': 1
# 'congressional': 1
# 'congress?': 1
# 'congress': 5
# 'congratulations,': 1
# 'congratulations': 1
# 'conflict': 1
# 'conduct."': 1
# 'conditions': 1
# 'condemning': 1
# 'complaining': 1
# 'complained': 1
# 'company."': 1
# 'company,': 1
# 'company': 2
# 'companies?': 1
# 'companies.': 3
# 'companies,': 2
# 'companies': 10
# 'compactors': 1
# 'compactor': 1
# 'communities.': 1
# 'committed': 1
# 'commicast.': 1
# 'coming."': 1
# 'coming.': 1
# 'coming': 18
# 'comey,': 1
# 'comey's': 1
# 'comey': 1
# 'comes': 7
# 'come?': 2
# 'come.': 4
# 'come': 36
# 'colleges': 2
# 'collar': 3
# 'cold': 1
# 'cnn,': 1
# 'cnn': 1
# 'clue.': 1
# 'clown?': 1
# 'closing': 2
# 'closed': 1
# 'close.': 2
# 'close': 7
# 'clinton,': 2
# 'clinton's': 1
# 'clinton': 2
# 'climate': 1
# 'cleaning': 1
# 'cleanest': 2
# 'clean,': 1
# 'clean': 3
# 'city.': 1
# 'citizens,': 1
# 'citizens': 3
# 'cities.': 2
# 'cities,': 2
# 'cities"': 1
# 'cities': 4
# 'chuck,': 2
# 'chuck': 4
# 'chrysler': 1
# 'christmas.': 1
# 'christmas,': 2
# 'christmas!': 1
# 'christmas': 2
# 'choices,': 1
# 'choice.': 2
# 'choice,': 1
# 'choice': 1
# 'china.': 1
# 'china,': 4
# 'china's': 1
# 'china': 2
# 'children.': 1
# 'children': 2
# 'childhood': 1
# 'child': 1
# 'check,': 1
# 'check': 1
# 'cheapened': 2
# 'chatfield.': 1
# 'chart,': 1
# 'charges': 1
# 'charged': 1
# 'charade.': 1
# 'characters,': 1
# 'changing': 1
# 'changed': 2
# 'change.': 1
# 'change': 1
# 'chance': 1
# 'champagne': 1
# 'chairwoman,': 2
# 'chairman': 1
# 'chair.': 1
# 'chair': 1
# 'central': 3
# 'center': 3
# 'celebrate': 1
# 'ceiling': 1
# 'ceding': 1
# 'causes': 1
# 'caused': 1
# 'cause': 1
# 'catch': 4
# 'casting,': 1
# 'casino,': 1
# 'cash?': 1
# 'cash.': 2
# 'cash': 1
# 'cases': 1
# 'case,': 2
# 'case': 1
# 'cars.': 2
# 'carolyn': 3
# 'carolina': 1
# 'care.': 3
# 'care': 15
# 'caravan': 1
# 'car."': 1
# 'car': 8
# 'capped': 1
# 'capital': 1
# 'cancer': 1
# 'canada.': 4
# 'can.': 3
# 'can't…"': 1
# 'can't."': 1
# 'can't': 14
# 'can': 27
# 'campaigned': 1
# 'campaign.': 1
# 'campaign-': 1
# 'campaign': 1
# 'cameras,': 1
# 'cameras': 2
# 'camera': 1
# 'came': 18
# 'calls': 5
# 'calling': 1
# 'called': 7
# 'call': 14
# 'california,': 1
# 'c': 1
# 'by': 39
# 'buying': 1
# 'buy,': 1
# 'buy': 3
# 'buttigieg?': 1
# 'buttigieg.': 1
# 'buttigieg,': 2
# 'buttigieg!': 1
# 'buttigieg': 1
# 'but,': 2
# 'but': 163
# 'bust.': 1
# 'business?': 1
# 'business.': 3
# 'business,': 1
# 'business': 3
# 'bush,': 2
# 'bureaucracy': 1
# 'bunch': 1
# 'bulbs?': 1
# 'bulb.': 3
# 'bulb,': 2
# 'bulb': 2
# 'building.': 2
# 'building': 8
# 'build.': 1
# 'build': 2
# 'budget."': 1
# 'budget.': 1
# 'budget,'': 1
# 'bucks.': 1
# 'bucks,': 1
# 'brutally': 1
# 'brutal': 2
# 'brought': 1
# 'broken': 1
# 'bringing': 6
# 'bring': 13
# 'breakthroughs': 1
# 'breaking': 1
# 'break.': 2
# 'break': 2
# 'branded': 1
# 'brand': 2
# 'branch': 2
# 'boy,': 1
# 'box,': 1
# 'box': 2
# 'bowman,': 1
# 'bought': 2
# 'bottom': 1
# 'bottle.': 1
# 'both': 1
# 'boring.': 1
# 'borders,': 2
# 'border,': 1
# 'border': 3
# 'boot': 1
# 'boom,': 3
# 'boo!': 3
# 'body': 1
# 'blue': 3
# 'blow': 1
# 'blood,': 1
# 'blinking.': 1
# 'blatant': 1
# 'black': 2
# 'bitch."': 1
# 'bit.': 1
# 'bit': 3
# 'birth.': 1
# 'bind': 1
# 'bills.': 1
# 'billions,': 2
# 'billions': 8
# 'billion,': 3
# 'billion': 16
# 'bill': 3
# 'biggest.': 1
# 'biggest': 4
# 'bigger,': 1
# 'bigger': 2
# 'big."': 1
# 'big,': 2
# 'big': 27
# 'biden,': 1
# 'biden': 3
# 'bible,': 1
# 'bias.': 1
# 'beyond': 1
# 'better."': 2
# 'better.': 3
# 'better': 15
# 'beto?': 1
# 'beto,': 1
# 'best."': 1
# 'best.': 3
# 'best,': 4
# 'best': 19
# 'beloved': 1
# 'belong.': 1
# 'believed': 2
# 'believe': 14
# 'being.': 1
# 'being': 7
# 'behind': 2
# 'beginning.': 1
# 'beginning,': 1
# 'beg': 1
# 'before.': 7
# 'before,': 3
# 'before': 14
# 'been': 28
# 'becomes': 2
# 'become': 2
# 'because,': 1
# 'because': 94
# 'became': 2
# 'beauty.': 1
# 'beauty,': 1
# 'beauty': 1
# 'beautifully': 1
# 'beautiful.': 1
# 'beautiful,': 1
# 'beautiful': 12
# 'beating': 3
# 'beat,': 1
# 'beat': 1
# 'bear': 1
# 'beaches.': 1
# 'beaches': 1
# 'be.': 1
# 'be,': 1
# 'be': 76
# 'battle': 3
# 'bathroom,': 1
# 'basketball': 1
# 'basically,': 1
# 'basically': 1
# 'basements.': 1
# 'based': 5
# 'barriers.': 1
# 'barriers': 2
# 'baron': 1
# 'barack': 1
# 'band': 1
# 'ballots': 1
# 'ballot': 2
# 'badly.': 1
# 'badly': 1
# 'bad.': 2
# 'bad,': 3
# 'bad': 12
# 'backs': 1
# 'backlash': 1
# 'back."': 2
# 'back.': 20
# 'back': 23
# 'baby."': 1
# 'baby's': 1
# 'baby': 1
# 'babies': 1
# 'b.': 1
# 'b+,': 1
# 'b': 1
# 'a…': 1
# 'awfully': 1
# 'away.': 2
# 'away,': 1
# 'away': 5
# 'awarded': 1
# 'avoid': 1
# 'autoworker,': 1
# 'automobiles': 1
# 'auto': 11
# 'authorities': 1
# 'audience.': 1
# 'attorney': 5
# 'attacks': 1
# 'attacking': 1
# 'attacked': 1
# 'at,': 2
# 'at': 31
# 'as…': 1
# 'asylum.': 1
# 'assume': 1
# 'assembly,': 1
# 'assembly': 2
# 'assaults': 1
# 'assault': 1
# 'ass?': 1
# 'ass,': 1
# 'ass': 2
# 'asking': 2
# 'asked': 5
# 'asians,': 1
# 'asia,': 1
# 'ashamed,': 1
# 'as,': 1
# 'as': 26
# 'artificial': 2
# 'arrested.': 1
# 'arrested': 1
# 'arrest': 1
# 'around.': 1
# 'around,': 1
# 'around': 5
# 'arms.': 1
# 'armed': 2
# 'arenas.': 1
# 'arenas,': 1
# 'arena."': 2
# 'arena.': 2
# 'aren't': 3
# 'areas,': 2
# 'areas': 1
# 'area,': 2
# 'area': 1
# 'are?': 1
# 'are."': 1
# 'are.': 1
# 'are,': 3
# 'are': 99
# 'approving': 1
# 'approved.': 2
# 'approved,': 1
# 'approved': 1
# 'approval': 1
# 'appreciate': 3
# 'appointed': 1
# 'appeal,': 1
# 'apologized.': 1
# 'apologize."': 1
# 'apologize.': 2
# 'apologies': 1
# 'apart': 1
# 'anyway,': 5
# 'anytime': 1
# 'anything.': 5
# 'anything,': 1
# 'anything': 10
# 'anyone': 1
# 'anymore."': 2
# 'anymore.': 3
# 'anymore,': 1
# 'anymore': 1
# 'anybody's': 1
# 'anybody': 10
# 'any': 12
# 'answered,': 1
# 'answer,': 1
# 'answer': 2
# 'another': 10
# 'announced': 5
# 'announce,': 1
# 'animals.': 1
# 'animal.': 1
# 'angry': 1
# 'angeles': 1
# 'and,"': 1
# 'and': 494
# 'an': 30
# 'amount': 1
# 'among': 2
# 'ammunition."': 1
# 'americans.': 2
# 'americans,': 1
# 'americans': 1
# 'american.': 1
# 'american': 18
# 'america.': 3
# 'america's': 3
# 'america': 11
# 'amazing.': 2
# 'am.': 1
# 'am,': 1
# 'always': 19
# 'although': 1
# 'alternatives': 1
# 'alternative.': 2
# 'alternative,': 2
# 'also': 5
# 'alright.': 1
# 'along.': 1
# 'along': 1
# 'alone': 1
# 'almost': 5
# 'allowing': 2
# 'allowed': 3
# 'allow': 2
# 'allegiance': 2
# 'all,': 2
# 'all': 82
# 'aliens,': 1
# 'aliens': 3
# 'alien': 2
# 'alfred': 1
# 'alan': 1
# 'air.': 2
# 'air': 3
# 'ainsley': 1
# 'ain't': 1
# 'aids': 2
# 'aid.': 1
# 'ahead': 2
# 'ah."': 1
# 'ah,': 2
# 'agreements': 1
# 'agreement': 2
# 'agree.': 2
# 'ago?': 1
# 'ago.': 8
# 'ago,': 4
# 'ago': 7
# 'aggressive.': 1
# 'aggressive': 1
# 'against': 9
# 'again?': 1
# 'again.': 10
# 'again,': 3
# 'again': 1
# 'after': 5
# 'african-american': 1
# 'african': 3
# 'affronted,': 1
# 'admitted': 1
# 'administrations,': 1
# 'administration': 1
# 'adjustment.': 1
# 'add': 1
# 'adam': 1
# 'actually.': 3
# 'actually,': 1
# 'actually': 5
# 'acts': 1
# 'actions': 2
# 'acted-".': 1
# 'act': 2
# 'achieving': 1
# 'achieve': 1
# 'accusing': 1
# 'accused,': 1
# 'accord.': 1
# 'accomplishing.': 1
# 'accomplishing': 1
# 'abusive': 1
# 'absolute,"': 1
# 'absolute': 2
# 'abraham': 1
# 'above': 1
# 'about."': 1
# 'about.': 5
# 'about,': 2
# 'about': 66
# 'abortion,': 2
# 'abortion': 1
# 'able': 4
# 'a,': 1
# 'a+,': 2
# 'a+': 1
# 'a': 361
# '975.': 1
# '97%,': 1
# '93': 1
# '92%': 1
# '90,': 1
# '90%,': 1
# '82%.': 1
# '80,000,': 1
# '75%': 1
# '72%,': 1
# '71': 4
# '70,000,': 1
# '"12': 1
# '"': 8

# %%
# Exercise 02
import findspark
findspark.init()
from pyspark import SparkContext

sc = SparkContext(appName="Excercise02", master="spark://namenode:7077")
input_file = "/data/BattleCreekDec19_2019.txt"
lines = sc.textFile(input_file)

# 2. Extract words and filter out empty strings
words = lines.flatMap(lambda line: line.split(" ")) \
             .filter(lambda word: word != "") \
             .map(lambda word: word.strip().strip('.,!?:;()')) \
             .filter(lambda word: word != "")

# 3. Map each word to (length, 1) to prepare for sum and count
# (word_length, count)
word_stats = words.map(lambda word: (len(word), 1))

# 4. Reduce to get total length and total word count
# aggregate = (total_length, total_word_count)
total_length, total_count = word_stats.reduce(lambda x, y: (x[0] + y[0], x[1] + y[1]))

# 5. Calculate average
if total_count > 0:
    average_length = total_length / total_count
    print(f"Total Words: {total_count}")
    print(f"Total Characters: {total_length}")
    print(f"Average Word Length: {average_length:.2f}")
else:
    print("No words found.")

sc.stop()
# Out:
# Total Words: 17830
# Total Characters: 74715
# Average Word Length: 4.19

# %%
# Exercise 03
import findspark
findspark.init()
from pyspark import SparkContext

sc = SparkContext(appName="Excercise03", master="spark://namenode:7077")
input_file = "/data/BattleCreekDec19_2019.txt"

counts = sc.textFile(input_file) \
           .flatMap(lambda line: line.split(" ")) \
           .filter(lambda word: word != "") \
           .map(lambda word: (word.lower().strip(), 1)) \
           .reduceByKey(lambda a, b: a + b)

for word, count in counts.takeOrdered(10, key=lambda x: -x[1]):
    print(f"'{word}': {count}")

sc.stop()
# Out:
# 'the': 698
# 'and': 494
# 'i': 491
# 'to': 422
# 'you': 392
# 'a': 361
# 'they': 316
# 'of': 308
# 'we': 251
# 'in': 196

# %%
# Exercise 04
import findspark
findspark.init()
from pyspark import SparkContext

sc = SparkContext(appName="Excercise04", master="spark://namenode:7077")

# Define paths (using /data/ as per your notebook convention)
path1 = "/data/BattleCreekDec19_2019.txt"
path2 = "/data/BemidjiSep18_2020.txt"

# Helper function for word count RDD
def get_word_counts(file_path):
    return sc.textFile(file_path) \
             .flatMap(lambda line: line.split(" ")) \
             .map(lambda word: word.lower().strip().strip('.,!?:;()')) \
             .filter(lambda word: word != "") \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)

# Create two RDDs of (word, count)
rdd1 = get_word_counts(path1)
rdd2 = get_word_counts(path2)

# Perform Inner Join
# Result format: (word, (count_from_file1, count_from_file2))
joined_rdd = rdd1.join(rdd2)

# Sort by combined frequency for display
sorted_joined = joined_rdd.sortBy(lambda x: -(x[1][0] + x[1][1]))

# Collect ALL results to the driver
all_joined_results = sorted_joined.collect()

print(f"Inner Join Results: {len(all_joined_results)} words present in BOTH files")
print("-" * 50)
for word, counts in all_joined_results:
    count1, count2 = counts
    print(f"'{word}': BattleCreek={count1}, Bemidji={count2}")

sc.stop()
# Out:
# Inner Join Results: 1072 words present in BOTH files
# --------------------------------------------------
# 'the': BattleCreek=698, Bemidji=612
# 'and': BattleCreek=494, Bemidji=488
# 'i': BattleCreek=491, Bemidji=459
# 'building': BattleCreek=10, Bemidji=3
# 'proud': BattleCreek=6, Bemidji=7
# 'court': BattleCreek=10, Bemidji=3
# 'forget': BattleCreek=5, Bemidji=8
# 'office': BattleCreek=8, Bemidji=5
# 'crime': BattleCreek=8, Bemidji=5
# 'gone': BattleCreek=4, Bemidji=9
# 'auto': BattleCreek=11, Bemidji=1
# 'york': BattleCreek=3, Bemidji=9
# 'help': BattleCreek=10, Bemidji=2
# '"how': BattleCreek=3, Bemidji=9
# 'business': BattleCreek=8, Bemidji=4
# 'crooked': BattleCreek=9, Bemidji=3
# 'polls': BattleCreek=7, Bemidji=5
# 'though': BattleCreek=7, Bemidji=5
# 'around': BattleCreek=7, Bemidji=5
# 'jail': BattleCreek=2, Bemidji=10
# 'statement': BattleCreek=9, Bemidji=3
# 'together': BattleCreek=7, Bemidji=5
# 'tremendous': BattleCreek=5, Bemidji=7
# 'word': BattleCreek=9, Bemidji=3
# 'happy': BattleCreek=7, Bemidji=5
# 'half': BattleCreek=5, Bemidji=7
# 'taking': BattleCreek=8, Bemidji=4
# 'buy': BattleCreek=4, Bemidji=8
# 'whole': BattleCreek=6, Bemidji=6
# 'allowed': BattleCreek=3, Bemidji=9
# 'prices': BattleCreek=9, Bemidji=3
# 'closed': BattleCreek=1, Bemidji=11
# 'rid': BattleCreek=3, Bemidji=8
# 'wonderful': BattleCreek=8, Bemidji=3
# 'planes': BattleCreek=5, Bemidji=6
# 'fight': BattleCreek=4, Bemidji=7
# 'thought': BattleCreek=5, Bemidji=6
# 'told': BattleCreek=6, Bemidji=5
# '"': BattleCreek=8, Bemidji=3
# 'nice': BattleCreek=2, Bemidji=9
# 'unbelievable': BattleCreek=4, Bemidji=7
# 'asked': BattleCreek=5, Bemidji=6
# 'signed': BattleCreek=1, Bemidji=10
# 'sir."': BattleCreek=6, Bemidji=5
# 'comes': BattleCreek=7, Bemidji=4
# 'standing': BattleCreek=3, Bemidji=8
# 'mayor': BattleCreek=6, Bemidji=5
# 'sanctuary': BattleCreek=10, Bemidji=1
# 'cities': BattleCreek=8, Bemidji=3
# 'worse': BattleCreek=4, Bemidji=6
# 'worst': BattleCreek=5, Bemidji=5
# 'price': BattleCreek=1, Bemidji=9
# 'biggest': BattleCreek=5, Bemidji=5
# 'weapons': BattleCreek=2, Bemidji=8
# 'turn': BattleCreek=4, Bemidji=6
# 'sounds': BattleCreek=3, Bemidji=7
# 'period': BattleCreek=9, Bemidji=1
# 'days': BattleCreek=3, Bemidji=7
# 'couldn't': BattleCreek=3, Bemidji=7
# 'beat': BattleCreek=2, Bemidji=8
# 'read': BattleCreek=9, Bemidji=1
# 'looked': BattleCreek=3, Bemidji=7
# 'republicans': BattleCreek=9, Bemidji=1
# 'phone': BattleCreek=3, Bemidji=7
# 'judges': BattleCreek=8, Bemidji=2
# 'governor': BattleCreek=2, Bemidji=8
# 'far': BattleCreek=6, Bemidji=4
# 'ripping': BattleCreek=3, Bemidji=7
# 'makes': BattleCreek=6, Bemidji=4
# 'bit': BattleCreek=4, Bemidji=6
# 'almost': BattleCreek=5, Bemidji=5
# 'crowds': BattleCreek=8, Bemidji=2
# 'appreciate': BattleCreek=3, Bemidji=7
# 'next': BattleCreek=2, Bemidji=8
# 'running': BattleCreek=2, Bemidji=8
# 'nine': BattleCreek=2, Bemidji=8
# 'haven't': BattleCreek=2, Bemidji=8
# 'who's': BattleCreek=6, Bemidji=4
# 'giving': BattleCreek=8, Bemidji=2
# 'protect': BattleCreek=7, Bemidji=3
# 'energy': BattleCreek=4, Bemidji=6
# 'gas': BattleCreek=8, Bemidji=2
# 'guns': BattleCreek=5, Bemidji=5
# 'lincoln': BattleCreek=2, Bemidji=8
# 'industry': BattleCreek=7, Bemidji=3
# 'happening': BattleCreek=7, Bemidji=2
# 'manufacturing': BattleCreek=8, Bemidji=1
# 'worry': BattleCreek=7, Bemidji=2
# 'poll': BattleCreek=1, Bemidji=8
# 'mention': BattleCreek=5, Bemidji=4
# 'calls': BattleCreek=5, Bemidji=4
# 'wisconsin': BattleCreek=5, Bemidji=4
# '"what': BattleCreek=2, Bemidji=7
# 'i'd': BattleCreek=3, Bemidji=6
# 'happen': BattleCreek=4, Bemidji=5
# 'single': BattleCreek=3, Bemidji=6
# 'anymore': BattleCreek=5, Bemidji=4
# 'week': BattleCreek=1, Bemidji=8
# 'phony': BattleCreek=6, Bemidji=3
# 'nation': BattleCreek=7, Bemidji=2
# 'jefferson': BattleCreek=1, Bemidji=8
# 'that."': BattleCreek=4, Bemidji=5
# 'places': BattleCreek=5, Bemidji=4
# 'car': BattleCreek=8, Bemidji=1
# 'real': BattleCreek=5, Bemidji=4
# 'wait': BattleCreek=6, Bemidji=3
# 'minute': BattleCreek=3, Bemidji=6
# '"don't': BattleCreek=8, Bemidji=1
# 'less': BattleCreek=8, Bemidji=1
# 'powerful': BattleCreek=4, Bemidji=5
# 'ones': BattleCreek=7, Bemidji=2
# 'bigger': BattleCreek=3, Bemidji=6
# 'telling': BattleCreek=6, Bemidji=3
# 'imagine': BattleCreek=3, Bemidji=6
# 'drugs': BattleCreek=2, Bemidji=7
# 'having': BattleCreek=1, Bemidji=8
# 'press': BattleCreek=5, Bemidji=4
# 'land': BattleCreek=6, Bemidji=3
# 'criminal': BattleCreek=4, Bemidji=5
# 'hit': BattleCreek=1, Bemidji=8
# 'trade': BattleCreek=6, Bemidji=2
# 'fine': BattleCreek=6, Bemidji=2
# 'deals': BattleCreek=7, Bemidji=1
# 'check': BattleCreek=2, Bemidji=6
# '"it's': BattleCreek=5, Bemidji=3
# 'fighting': BattleCreek=5, Bemidji=3
# 'watch': BattleCreek=4, Bemidji=4
# 'wasn't': BattleCreek=5, Bemidji=3
# 'dishonest': BattleCreek=6, Bemidji=2
# 'means': BattleCreek=5, Bemidji=3
# 'damn': BattleCreek=4, Bemidji=4
# 'may': BattleCreek=5, Bemidji=3
# 'disgrace': BattleCreek=6, Bemidji=2
# 'beauty': BattleCreek=3, Bemidji=5
# 'simple': BattleCreek=5, Bemidji=3
# 'attorney': BattleCreek=5, Bemidji=3
# 'enthusiasm': BattleCreek=1, Bemidji=7
# 'try': BattleCreek=6, Bemidji=2
# 'ended': BattleCreek=7, Bemidji=1
# 'still': BattleCreek=2, Bemidji=6
# 'here's': BattleCreek=5, Bemidji=3
# 'along': BattleCreek=2, Bemidji=6
# 'korea': BattleCreek=4, Bemidji=4
# 'else': BattleCreek=5, Bemidji=3
# 'radical': BattleCreek=2, Bemidji=6
# 'outside': BattleCreek=5, Bemidji=3
# 'woman': BattleCreek=7, Bemidji=1
# 'hope': BattleCreek=4, Bemidji=4
# 'write': BattleCreek=6, Bemidji=2
# 'might': BattleCreek=7, Bemidji=1
# 'front': BattleCreek=4, Bemidji=4
# 'hundred': BattleCreek=3, Bemidji=5
# 'drug': BattleCreek=7, Bemidji=1
# 'border': BattleCreek=4, Bemidji=4
# 'strong': BattleCreek=4, Bemidji=4
# 'weak': BattleCreek=4, Bemidji=4
# 'supreme': BattleCreek=5, Bemidji=3
# 'debate': BattleCreek=2, Bemidji=6
# 'where's': BattleCreek=2, Bemidji=6
# 'administration': BattleCreek=1, Bemidji=7
# 'steel': BattleCreek=7, Bemidji=1
# 'north': BattleCreek=1, Bemidji=7
# 'words': BattleCreek=4, Bemidji=4
# 'germany': BattleCreek=5, Bemidji=3
# 'kind': BattleCreek=3, Bemidji=4
# 'wants': BattleCreek=5, Bemidji=2
# 'massive': BattleCreek=4, Bemidji=3
# 'making': BattleCreek=5, Bemidji=2
# 'power': BattleCreek=4, Bemidji=3
# 'idea': BattleCreek=2, Bemidji=5
# 'able': BattleCreek=4, Bemidji=3
# 'numbers': BattleCreek=6, Bemidji=1
# 'round': BattleCreek=4, Bemidji=3
# '50': BattleCreek=3, Bemidji=4
# 'he'd': BattleCreek=4, Bemidji=3
# 'millions': BattleCreek=4, Bemidji=3
# 'instinct': BattleCreek=4, Bemidji=3
# 'television': BattleCreek=3, Bemidji=4
# 'name': BattleCreek=1, Bemidji=6
# 'political': BattleCreek=2, Bemidji=5
# 'strength': BattleCreek=1, Bemidji=6
# 'loved': BattleCreek=4, Bemidji=3
# 'politicians': BattleCreek=5, Bemidji=2
# 'open': BattleCreek=5, Bemidji=2
# 'yet': BattleCreek=4, Bemidji=3
# 'paying': BattleCreek=5, Bemidji=2
# '24': BattleCreek=2, Bemidji=5
# 'worked': BattleCreek=2, Bemidji=5
# 'beto': BattleCreek=2, Bemidji=5
# 'increase': BattleCreek=1, Bemidji=6
# 'must': BattleCreek=3, Bemidji=4
# 'citizens': BattleCreek=4, Bemidji=3
# 'law': BattleCreek=2, Bemidji=5
# 'high': BattleCreek=2, Bemidji=5
# 'notice': BattleCreek=4, Bemidji=3
# 'taxes': BattleCreek=4, Bemidji=3
# 'farmers': BattleCreek=6, Bemidji=1
# 'nancy': BattleCreek=5, Bemidji=2
# 'break': BattleCreek=4, Bemidji=3
# 'spent': BattleCreek=3, Bemidji=4
# 'early': BattleCreek=4, Bemidji=3
# 'yesterday': BattleCreek=3, Bemidji=4
# 'sudden': BattleCreek=2, Bemidji=5
# 'also': BattleCreek=5, Bemidji=2
# 'table': BattleCreek=3, Bemidji=4
# 'enough': BattleCreek=4, Bemidji=3
# 'finally': BattleCreek=5, Bemidji=2
# 'problems': BattleCreek=3, Bemidji=4
# 'november': BattleCreek=5, Bemidji=2
# 'e': BattleCreek=1, Bemidji=6
# 'including': BattleCreek=4, Bemidji=3
# 'campaign': BattleCreek=2, Bemidji=5
# 'brought': BattleCreek=1, Bemidji=6
# 'isn't': BattleCreek=2, Bemidji=5
# 'fact': BattleCreek=3, Bemidji=4
# 'important': BattleCreek=3, Bemidji=4
# 'wall': BattleCreek=2, Bemidji=5
# 'least': BattleCreek=1, Bemidji=6
# 'saved': BattleCreek=2, Bemidji=5
# 'children': BattleCreek=3, Bemidji=4
# 'sick': BattleCreek=3, Bemidji=4
# 'lady': BattleCreek=4, Bemidji=2
# 'feel': BattleCreek=4, Bemidji=2
# 'negotiated': BattleCreek=2, Bemidji=4
# 'sitting': BattleCreek=2, Bemidji=4
# 'honor': BattleCreek=3, Bemidji=3
# 'hate': BattleCreek=4, Bemidji=2
# 'stand': BattleCreek=3, Bemidji=3
# 'clinton': BattleCreek=4, Bemidji=2
# 'based': BattleCreek=5, Bemidji=1
# 'pretty': BattleCreek=5, Bemidji=1
# 'cnn': BattleCreek=2, Bemidji=4
# 'insurance': BattleCreek=5, Bemidji=1
# 'ought': BattleCreek=5, Bemidji=1
# 'sent': BattleCreek=3, Bemidji=3
# 'smart': BattleCreek=2, Bemidji=4
# 'foreign': BattleCreek=4, Bemidji=2
# 'approved': BattleCreek=4, Bemidji=2
# 'justices': BattleCreek=4, Bemidji=2
# 'changed': BattleCreek=2, Bemidji=4
# 'question': BattleCreek=3, Bemidji=3
# 'line': BattleCreek=2, Bemidji=4
# 'spending': BattleCreek=4, Bemidji=2
# 'miles': BattleCreek=2, Bemidji=4
# 'act': BattleCreek=2, Bemidji=4
# 'abraham': BattleCreek=1, Bemidji=5
# 'medical': BattleCreek=2, Bemidji=4
# 'gentlemen': BattleCreek=1, Bemidji=5
# 'fantastic': BattleCreek=2, Bemidji=4
# 'anyway': BattleCreek=5, Bemidji=1
# 'south': BattleCreek=5, Bemidji=1
# 'favor': BattleCreek=5, Bemidji=1
# 'gives': BattleCreek=5, Bemidji=1
# 'white': BattleCreek=2, Bemidji=4
# '"we': BattleCreek=3, Bemidji=3
# 'such': BattleCreek=3, Bemidji=3
# 'gotten': BattleCreek=2, Bemidji=4
# 'easy': BattleCreek=4, Bemidji=2
# 'wife': BattleCreek=3, Bemidji=3
# 'announced': BattleCreek=5, Bemidji=1
# 'dying': BattleCreek=5, Bemidji=1
# 'choice': BattleCreek=4, Bemidji=2
# 'everyone': BattleCreek=4, Bemidji=2
# 'amazing': BattleCreek=2, Bemidji=4
# 'tonight': BattleCreek=3, Bemidji=3
# 'friend': BattleCreek=1, Bemidji=5
# 'moved': BattleCreek=2, Bemidji=4
# 'total': BattleCreek=3, Bemidji=3
# 'report': BattleCreek=4, Bemidji=2
# 'angry': BattleCreek=1, Bemidji=5
# 'healthcare': BattleCreek=5, Bemidji=1
# 'helped': BattleCreek=3, Bemidji=3
# 'ukraine': BattleCreek=5, Bemidji=1
# 'dangerous': BattleCreek=3, Bemidji=3
# 'elected': BattleCreek=4, Bemidji=2
# 'answer': BattleCreek=3, Bemidji=3
# 'oil': BattleCreek=3, Bemidji=3
# 'either': BattleCreek=3, Bemidji=3
# 'smaller': BattleCreek=3, Bemidji=3
# 'vice': BattleCreek=1, Bemidji=4
# 'thrilled': BattleCreek=3, Bemidji=2
# 'nobody's': BattleCreek=3, Bemidji=2
# 'seven': BattleCreek=3, Bemidji=2
# '40': BattleCreek=3, Bemidji=2
# 'seriously': BattleCreek=2, Bemidji=3
# 'security': BattleCreek=1, Bemidji=4
# 'sure': BattleCreek=2, Bemidji=3
# 'start': BattleCreek=4, Bemidji=1
# 'young': BattleCreek=3, Bemidji=2
# 'usa': BattleCreek=4, Bemidji=1
# 'sometimes': BattleCreek=2, Bemidji=3
# 'central': BattleCreek=3, Bemidji=2
# 'schools': BattleCreek=3, Bemidji=2
# 'area': BattleCreek=3, Bemidji=2
# 'michelle': BattleCreek=1, Bemidji=4
# 'until': BattleCreek=4, Bemidji=1
# 'looks': BattleCreek=4, Bemidji=1
# 'ass': BattleCreek=4, Bemidji=1
# 'stupid': BattleCreek=2, Bemidji=3
# '"yes': BattleCreek=1, Bemidji=4
# 'fbi': BattleCreek=4, Bemidji=1
# '100': BattleCreek=4, Bemidji=1
# '"that's': BattleCreek=4, Bemidji=1
# 'head': BattleCreek=3, Bemidji=2
# 'aren't': BattleCreek=3, Bemidji=2
# 'point': BattleCreek=2, Bemidji=3
# 'change': BattleCreek=2, Bemidji=3
# '"do': BattleCreek=3, Bemidji=2
# '"he': BattleCreek=1, Bemidji=4
# '"but': BattleCreek=2, Bemidji=3
# 'worker': BattleCreek=4, Bemidji=1
# 'cut': BattleCreek=2, Bemidji=3
# 'short': BattleCreek=3, Bemidji=2
# 'send': BattleCreek=2, Bemidji=3
# 'cash': BattleCreek=4, Bemidji=1
# 'iran': BattleCreek=3, Bemidji=2
# 'france': BattleCreek=3, Bemidji=2
# 'working': BattleCreek=2, Bemidji=3
# 'it?"': BattleCreek=1, Bemidji=4
# 'starting': BattleCreek=1, Bemidji=4
# 'build': BattleCreek=3, Bemidji=2
# 'sell': BattleCreek=4, Bemidji=1
# 'union': BattleCreek=4, Bemidji=1
# 'company': BattleCreek=3, Bemidji=2
# 'second': BattleCreek=2, Bemidji=3
# 'level': BattleCreek=2, Bemidji=3
# 'since': BattleCreek=3, Bemidji=2
# 'respect': BattleCreek=3, Bemidji=2
# 'finished': BattleCreek=4, Bemidji=1
# 'prime': BattleCreek=3, Bemidji=2
# 'rally': BattleCreek=3, Bemidji=2
# 'show': BattleCreek=4, Bemidji=1
# 'hard': BattleCreek=3, Bemidji=2
# 'fairness': BattleCreek=3, Bemidji=2
# 'deep': BattleCreek=1, Bemidji=4
# 'march': BattleCreek=1, Bemidji=4
# '18': BattleCreek=4, Bemidji=1
# 'you."': BattleCreek=4, Bemidji=1
# 'knew': BattleCreek=3, Bemidji=2
# 'side': BattleCreek=2, Bemidji=3
# 'constitution': BattleCreek=3, Bemidji=2
# 'war': BattleCreek=2, Bemidji=3
# 'senate': BattleCreek=3, Bemidji=2
# 'men': BattleCreek=3, Bemidji=2
# 'frankly': BattleCreek=4, Bemidji=1
# 'post': BattleCreek=1, Bemidji=4
# 'yeah': BattleCreek=2, Bemidji=3
# 'knows': BattleCreek=1, Bemidji=4
# 'stay': BattleCreek=1, Bemidji=4
# 'whether': BattleCreek=1, Bemidji=4
# 'later': BattleCreek=1, Bemidji=4
# 'spend': BattleCreek=3, Bemidji=2
# 'clean': BattleCreek=4, Bemidji=1
# 'patriots': BattleCreek=3, Bemidji=1
# 'especially': BattleCreek=3, Bemidji=1
# 'sign': BattleCreek=3, Bemidji=1
# 'loves': BattleCreek=2, Bemidji=2
# 'shape': BattleCreek=1, Bemidji=3
# 'father': BattleCreek=2, Bemidji=2
# 'nuclear': BattleCreek=2, Bemidji=2
# 'crap': BattleCreek=1, Bemidji=3
# 'created': BattleCreek=3, Bemidji=1
# 'am': BattleCreek=2, Bemidji=2
# 'watching': BattleCreek=1, Bemidji=3
# 'secret': BattleCreek=2, Bemidji=2
# 'arenas': BattleCreek=2, Bemidji=2
# 'escalator': BattleCreek=2, Bemidji=2
# 'o'clock': BattleCreek=3, Bemidji=1
# 'speak': BattleCreek=3, Bemidji=1
# 'tried': BattleCreek=2, Bemidji=2
# 'human': BattleCreek=2, Bemidji=2
# 'you'd': BattleCreek=3, Bemidji=1
# 'walk': BattleCreek=3, Bemidji=1
# 'pronounce': BattleCreek=2, Bemidji=2
# 'once': BattleCreek=2, Bemidji=2
# 'center': BattleCreek=3, Bemidji=1
# 'leaders': BattleCreek=3, Bemidji=1
# '"he's': BattleCreek=1, Bemidji=3
# 'tucker': BattleCreek=1, Bemidji=3
# 'perfect': BattleCreek=2, Bemidji=2
# 'sad': BattleCreek=2, Bemidji=2
# 'lots': BattleCreek=3, Bemidji=1
# 'thousand': BattleCreek=1, Bemidji=3
# 'quality': BattleCreek=1, Bemidji=3
# 'bunch': BattleCreek=1, Bemidji=3
# '20': BattleCreek=2, Bemidji=2
# 'names': BattleCreek=1, Bemidji=3
# 'rallies': BattleCreek=3, Bemidji=1
# 'stadium': BattleCreek=2, Bemidji=2
# 'yes': BattleCreek=1, Bemidji=3
# 'killed': BattleCreek=1, Bemidji=3
# 'wear': BattleCreek=2, Bemidji=2
# 'lost': BattleCreek=1, Bemidji=3
# 'putting': BattleCreek=1, Bemidji=3
# 'safe': BattleCreek=3, Bemidji=1
# 'crying': BattleCreek=2, Bemidji=2
# 'late': BattleCreek=3, Bemidji=1
# 'fee': BattleCreek=1, Bemidji=3
# 'save': BattleCreek=1, Bemidji=3
# 'boy': BattleCreek=1, Bemidji=3
# 'poor': BattleCreek=1, Bemidji=3
# 'science': BattleCreek=1, Bemidji=3
# 'using': BattleCreek=2, Bemidji=2
# 'ladies': BattleCreek=1, Bemidji=3
# 'promised': BattleCreek=3, Bemidji=1
# 'politics': BattleCreek=1, Bemidji=3
# 'fun': BattleCreek=2, Bemidji=2
# 'talked': BattleCreek=3, Bemidji=1
# 'credit': BattleCreek=2, Bemidji=2
# 'piece': BattleCreek=2, Bemidji=2
# 'grandfather': BattleCreek=1, Bemidji=3
# 'we'd': BattleCreek=1, Bemidji=3
# 'historically': BattleCreek=2, Bemidji=2
# 'top': BattleCreek=2, Bemidji=2
# 'sorry': BattleCreek=3, Bemidji=1
# 'florida': BattleCreek=3, Bemidji=1
# 'sort': BattleCreek=1, Bemidji=3
# '"trump': BattleCreek=2, Bemidji=2
# 'witch': BattleCreek=3, Bemidji=1
# 'bill': BattleCreek=3, Bemidji=1
# 'six': BattleCreek=1, Bemidji=3
# 'reason': BattleCreek=3, Bemidji=1
# 'immediately': BattleCreek=1, Bemidji=3
# '15': BattleCreek=2, Bemidji=2
# '"wait': BattleCreek=2, Bemidji=2
# 'friends': BattleCreek=2, Bemidji=2
# 'shame': BattleCreek=1, Bemidji=3
# 'part': BattleCreek=2, Bemidji=2
# 'owned': BattleCreek=1, Bemidji=3
# 'case': BattleCreek=3, Bemidji=1
# 'years."': BattleCreek=2, Bemidji=2
# 'watched': BattleCreek=2, Bemidji=2
# '100%': BattleCreek=3, Bemidji=1
# '"this': BattleCreek=2, Bemidji=2
# 'cost': BattleCreek=2, Bemidji=2
# 'allegiance': BattleCreek=2, Bemidji=2
# 'america's': BattleCreek=3, Bemidji=1
# 'justice': BattleCreek=3, Bemidji=1
# 'behind': BattleCreek=2, Bemidji=2
# 'fit': BattleCreek=1, Bemidji=3
# 'without': BattleCreek=1, Bemidji=3
# 'soon': BattleCreek=3, Bemidji=1
# 'drive': BattleCreek=3, Bemidji=1
# 'travel': BattleCreek=1, Bemidji=3
# 'battle': BattleCreek=3, Bemidji=1
# 'congressmen': BattleCreek=3, Bemidji=1
# 'bush': BattleCreek=2, Bemidji=2
# 'expensive': BattleCreek=2, Bemidji=2
# 'phenomenal': BattleCreek=2, Bemidji=2
# 'opening': BattleCreek=2, Bemidji=2
# 'recently': BattleCreek=3, Bemidji=1
# '"i'm': BattleCreek=1, Bemidji=3
# 'thugs': BattleCreek=1, Bemidji=3
# 'charged': BattleCreek=1, Bemidji=3
# 'finest': BattleCreek=1, Bemidji=3
# 'highly': BattleCreek=1, Bemidji=3
# 'hundreds': BattleCreek=2, Bemidji=2
# 'doctors': BattleCreek=1, Bemidji=3
# 'city': BattleCreek=1, Bemidji=3
# 'national': BattleCreek=1, Bemidji=3
# 'trust': BattleCreek=1, Bemidji=3
# 'weren't': BattleCreek=2, Bemidji=2
# 'estate': BattleCreek=2, Bemidji=2
# 'successful': BattleCreek=1, Bemidji=3
# 'tax': BattleCreek=2, Bemidji=1
# 'amount': BattleCreek=1, Bemidji=2
# 'spoke': BattleCreek=2, Bemidji=1
# '"look': BattleCreek=2, Bemidji=1
# 'you?"': BattleCreek=2, Bemidji=1
# 'stronger': BattleCreek=2, Bemidji=1
# 'trillion': BattleCreek=2, Bemidji=1
# 'casting': BattleCreek=1, Bemidji=2
# '"that': BattleCreek=2, Bemidji=1
# 'bought': BattleCreek=2, Bemidji=1
# 'forces': BattleCreek=2, Bemidji=1
# 'decades': BattleCreek=2, Bemidji=1
# 'space': BattleCreek=2, Bemidji=1
# 'month': BattleCreek=1, Bemidji=2
# 'higher': BattleCreek=2, Bemidji=1
# 'disaster': BattleCreek=2, Bemidji=1
# 'middle': BattleCreek=2, Bemidji=1
# 'pennsylvania': BattleCreek=2, Bemidji=1
# 'floor': BattleCreek=2, Bemidji=1
# 'depressed': BattleCreek=1, Bemidji=2
# 'forgot': BattleCreek=1, Bemidji=2
# 'mark': BattleCreek=1, Bemidji=2
# 'msnbc': BattleCreek=2, Bemidji=1
# 'allow': BattleCreek=2, Bemidji=1
# 'so."': BattleCreek=1, Bemidji=2
# 'shouldn't': BattleCreek=2, Bemidji=1
# 'page': BattleCreek=1, Bemidji=2
# 'million."': BattleCreek=1, Bemidji=2
# 'anyone': BattleCreek=1, Bemidji=2
# 'laura': BattleCreek=2, Bemidji=1
# 'walked': BattleCreek=1, Bemidji=2
# 'believed': BattleCreek=2, Bemidji=1
# 'absolute': BattleCreek=2, Bemidji=1
# 'lousy': BattleCreek=2, Bemidji=1
# 'known': BattleCreek=2, Bemidji=1
# 'elections': BattleCreek=2, Bemidji=1
# 'race': BattleCreek=1, Bemidji=2
# '"and': BattleCreek=2, Bemidji=1
# 'corruption': BattleCreek=2, Bemidji=1
# 'down."': BattleCreek=2, Bemidji=1
# 'george': BattleCreek=1, Bemidji=2
# 'turned': BattleCreek=1, Bemidji=2
# 'hunt': BattleCreek=2, Bemidji=1
# 'speaker': BattleCreek=1, Bemidji=2
# '"who's': BattleCreek=1, Bemidji=2
# 'regulation': BattleCreek=2, Bemidji=1
# 'maniacs': BattleCreek=2, Bemidji=1
# 'religion': BattleCreek=2, Bemidji=1
# 'u.s': BattleCreek=2, Bemidji=1
# 'considered': BattleCreek=1, Bemidji=2
# 'better."': BattleCreek=2, Bemidji=1
# 'acts': BattleCreek=1, Bemidji=2
# 'convicted': BattleCreek=2, Bemidji=1
# 'deadly': BattleCreek=1, Bemidji=2
# 'murder': BattleCreek=2, Bemidji=1
# 'families': BattleCreek=1, Bemidji=2
# 'thanks': BattleCreek=2, Bemidji=1
# 'patrol': BattleCreek=2, Bemidji=1
# 'extreme': BattleCreek=2, Bemidji=1
# 'people."': BattleCreek=1, Bemidji=2
# 'europe': BattleCreek=2, Bemidji=1
# 'defend': BattleCreek=2, Bemidji=1
# 'games': BattleCreek=1, Bemidji=2
# 'thomas': BattleCreek=1, Bemidji=2
# 'loyal': BattleCreek=1, Bemidji=2
# '"i'd': BattleCreek=1, Bemidji=2
# 'likes': BattleCreek=1, Bemidji=2
# 'hardworking': BattleCreek=1, Bemidji=2
# 'gasoline': BattleCreek=2, Bemidji=1
# 'a…': BattleCreek=1, Bemidji=2
# 'percent': BattleCreek=1, Bemidji=2
# 'playing': BattleCreek=2, Bemidji=1
# 'funny': BattleCreek=2, Bemidji=1
# 'people…': BattleCreek=1, Bemidji=2
# 'agree': BattleCreek=2, Bemidji=1
# '200': BattleCreek=1, Bemidji=2
# 'vets': BattleCreek=1, Bemidji=2
# '25': BattleCreek=2, Bemidji=1
# 'morning': BattleCreek=2, Bemidji=1
# 'speaking': BattleCreek=1, Bemidji=2
# 'mine': BattleCreek=1, Bemidji=2
# 'suppression': BattleCreek=1, Bemidji=2
# 'convention': BattleCreek=1, Bemidji=2
# 'met': BattleCreek=1, Bemidji=2
# 'clue': BattleCreek=1, Bemidji=2
# 'congratulations': BattleCreek=2, Bemidji=1
# 'harder': BattleCreek=2, Bemidji=1
# 'learned': BattleCreek=1, Bemidji=2
# 'meant': BattleCreek=1, Bemidji=2
# 'sean': BattleCreek=1, Bemidji=2
# 'hannity': BattleCreek=1, Bemidji=2
# 'mic': BattleCreek=2, Bemidji=1
# 'wow': BattleCreek=2, Bemidji=1
# 'learn': BattleCreek=1, Bemidji=2
# 'destroy': BattleCreek=2, Bemidji=1
# 'pledged': BattleCreek=2, Bemidji=1
# 'becomes': BattleCreek=2, Bemidji=1
# 'no."': BattleCreek=1, Bemidji=2
# 'dignity': BattleCreek=2, Bemidji=1
# 'list': BattleCreek=1, Bemidji=2
# 'stories': BattleCreek=1, Bemidji=2
# 'votes': BattleCreek=1, Bemidji=2
# 'lowest': BattleCreek=2, Bemidji=1
# 'everybody's': BattleCreek=1, Bemidji=2
# 'asking': BattleCreek=2, Bemidji=1
# 'planet': BattleCreek=2, Bemidji=1
# 'closing': BattleCreek=2, Bemidji=1
# 'handsome': BattleCreek=2, Bemidji=1
# 'course': BattleCreek=1, Bemidji=2
# 'mentioned': BattleCreek=2, Bemidji=1
# 'fast': BattleCreek=1, Bemidji=2
# 'except': BattleCreek=1, Bemidji=2
# 'truth': BattleCreek=1, Bemidji=2
# 'investment': BattleCreek=2, Bemidji=1
# 'its': BattleCreek=1, Bemidji=2
# 'few': BattleCreek=1, Bemidji=2
# 'earlier': BattleCreek=1, Bemidji=2
# 'broken': BattleCreek=1, Bemidji=2
# 'find': BattleCreek=1, Bemidji=2
# 'preexisting': BattleCreek=2, Bemidji=1
# 'ridiculous': BattleCreek=1, Bemidji=2
# 'extra': BattleCreek=1, Bemidji=2
# 'enforcement': BattleCreek=1, Bemidji=2
# 'walking': BattleCreek=1, Bemidji=2
# '30': BattleCreek=1, Bemidji=2
# 'taken': BattleCreek=1, Bemidji=2
# 'guarantee': BattleCreek=1, Bemidji=2
# 'both': BattleCreek=1, Bemidji=1
# 'me?"': BattleCreek=1, Bemidji=1
# 'presidents': BattleCreek=1, Bemidji=1
# 'movie': BattleCreek=1, Bemidji=1
# 'great."': BattleCreek=1, Bemidji=1
# '"because': BattleCreek=1, Bemidji=1
# 'sanctity': BattleCreek=1, Bemidji=1
# 'flag': BattleCreek=1, Bemidji=1
# 'returning': BattleCreek=1, Bemidji=1
# 'noticed': BattleCreek=1, Bemidji=1
# 'devotion': BattleCreek=1, Bemidji=1
# 'wealthy': BattleCreek=1, Bemidji=1

# %%
# Exercise 05
import findspark
findspark.init()
from pyspark import SparkContext

sc = SparkContext(appName="Excercise05", master="spark://namenode:7077")
input_file = "/data/BattleCreekDec19_2019.txt"

# 1. Load lines and split into words
raw_words = sc.textFile(input_file) \
              .flatMap(lambda line: line.split(" ")) \
              .map(lambda word: word.lower().strip().strip('.,!?:;()')) \
              .filter(lambda word: word != "")

# 2. Get unique words using .distinct()
unique_words_rdd = raw_words.distinct()

# 3. Count the results
total_unique = unique_words_rdd.count()

print(f"Total words (including duplicates): {raw_words.count()}")
print(f"Total unique words (duplicates removed): {total_unique}")

# Show a sample of 10 unique words
print("\nSample of unique words:")
print(unique_words_rdd.take(10))

sc.stop()
# Out:
# Total words (including duplicates): 17830
# Total unique words (duplicates removed): 2356
#
# Sample of unique words:
# ['vice', 'good', 'job', 'merry', 'christmas', 'michigan', 'we', 'in', 'was', 'of']

# %%
# Exercise 06: Apply NLP
import findspark
findspark.init()
from pyspark import SparkContext
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

sc.stop()
# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

sc = SparkContext(appName="Exercise06_NLP", master="spark://namenode:7077")
input_file = "/data/BattleCreekDec19_2019.txt"

# 1. Read dataset into RDD
lines = sc.textFile(input_file)

# Initialize NLP tools
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def clean_and_nlp(word):
    # Remove non-alphabetic characters and lowercase
    word = re.sub(r'[^a-zA-Z]', '', word).lower()
    if not word or word in stop_words:
        return None
    
    # Stemming
    stemmed = stemmer.stem(word)
    # Lemmatization
    lemmatized = lemmatizer.lemmatize(stemmed)
    
    return lemmatized

# 2. NLP Pipeline
# - Split into words
# - Clean and apply NLP (Filter out None/Empty)
# - Count unique words
words_rdd = lines.flatMap(lambda line: line.split(" ")) \
                 .map(clean_and_nlp) \
                 .filter(lambda x: x is not None and x != "")

# 3. Count unique words
word_counts_rdd = words_rdd.map(lambda word: (word, 1)) \
                           .reduceByKey(lambda a, b: a + b)

# Sort by count for visualization/reporting
sorted_word_counts = word_counts_rdd.sortBy(lambda x: x[1], ascending=False).collect()

print(f"Total Unique Meaningful Words: {len(sorted_word_counts)}")
print("\nTop 20 words:")
for word, count in sorted_word_counts[:20]:
    print(f"'{word}': {count}")

# 4. Visualize with WordCloud
word_freq_dict = dict(sorted_word_counts)

wc = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq_dict)

plt.figure(figsize=(15, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

sc.stop()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Total Unique Meaningful Words: 1531
#
# Top 20 words:
# 'said': 142
# 'go': 142
# 'know': 138
# 'dont': 129
# 'peopl': 112
# 'say': 108
# 'right': 93
# 'want': 89
# 'year': 85
# 'theyr': 84
# 'great': 79
# 'like': 77
# 'that': 76
# 'get': 76
# 'one': 75
# 'come': 69
# 'think': 65
# 'countri': 61
# 'time': 58
# 'thing': 54
